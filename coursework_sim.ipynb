# %%
import world
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # CW4

# %%
w = world.World()

# %%
w.draw_map()
w.draw_particles()
plt.imshow(w.display)

# %%
from math import pi
for j in range(4):
    for i in range(4):
        w.move_robot_forward(10)
        plt.figure()
        w.display_img()

    plt.figure()
    w.rotate_robot(pi/2.0)
    w.display_img()

# %% [markdown]
# # CW5
