# %%
import world
import matplotlib.pyplot as plt
from math import pi
# %matplotlib inline

# %% [markdown]
# # CW4

# %%
w = world.World()
w.draw_map()
w.draw_particles()
plt.imshow(w.display)

# %%
for j in range(4):
    for i in range(4):
        w.move_robot_forward(10)

    w.rotate_robot(pi/2.0)

# %% [markdown]
# # CW5

# %%
w = world.World()
w.draw_map()
w.draw_particles()
plt.imshow(w.display)

# %%
w.move_robot_to(84,30)
w.move_robot_to(180,30)
w.move_robot_to(180,54)
w.move_robot_to(138,54)
w.move_robot_to(138,168)
w.move_robot_to(114,168)
w.move_robot_to(114,84)
w.move_robot_to(84,84)
w.move_robot_to(84,30)

# %%
w = world.World()
w.draw_map()
w.draw_particles()
plt.imshow(w.display)

# %%
w.move_robot_to_slam(84,30)
w.move_robot_to_slam(180,30)
w.move_robot_to_slam(180,54)
w.move_robot_to_slam(138,54)
w.move_robot_to_slam(138,168)
w.move_robot_to_slam(114,168)
w.move_robot_to_slam(114,84)
w.move_robot_to_slam(84,84)
w.move_robot_to_slam(84,30)

# %% [markdown]
# # CW6

# %%
w = world.World()
w.draw_map()
w.draw_particles()
plt.imshow(w.display)

# %%
import random
import landmarks as lm
from sklearn.metrics import confusion_matrix
import pandas as pd

y_true = []
y_pred = []
correct = 0
count = 0
lm_correct = 0
for i in range(100):
    landmark_placed = i%5
    angle_placed = random.random()*2*pi-pi
    x_placed, y_placed = lm.positions[landmark_placed]
    w = world.World(starting_x=x_placed,starting_y=y_placed,starting_theta=angle_placed)
    pred_lm,pred_angle = w.find_landmark_and_orientation()
    print("true landmark = "+str(landmark_placed)+", landmark predicted = "+str(pred_lm)+", true angle = "+str(angle_placed*180.0/pi)+", predicted angle = "+str(pred_angle*180.0/pi))
    print("-------------------------")
    y_true.append(landmark_placed)
    y_pred.append(pred_lm)
    if y_true == y_pred:
        lm_correct +=1
    if (abs(angle_placed-pred_angle)*180.0/pi < 3):
        correct += 1
    count += 1
print(">>> lmark accuracy = "+str(100.0*lm_correct/count)+" %")
print(">>> angle accuracy = "+str(100.0*correct/count)+" %")
# Out:
# true landmark = 0, landmark predicted = 0, true angle = 48.782549274458404, predicted angle = 48.0
# -------------------------
# min error for landmark 1 = 27
# landmark 2 sse for angle 0.0 = 72
# landmark 2 sse for angle 3.0 = 70
# landmark 2 sse for angle 6.0 = 64
# landmark 2 sse for angle 9.0 = 62
# landmark 2 sse for angle 12.0 = 62
# landmark 2 sse for angle 15.0 = 60
# landmark 2 sse for angle 18.0 = 63
# landmark 2 sse for angle 21.0 = 65
# landmark 2 sse for angle 24.0 = 68
# landmark 2 sse for angle 27.0 = 70
# landmark 2 sse for angle 30.0 = 73
# landmark 2 sse for angle 33.0 = 73
# landmark 2 sse for angle 36.0 = 75
# landmark 2 sse for angle 39.0 = 77
# landmark 2 sse for angle 42.0 = 82
# landmark 2 sse for angle 45.0 = 81
# landmark 2 sse for angle 48.0 = 82
# landmark 2 sse for angle 51.0 = 84
# landmark 2 sse for angle 54.0 = 87
# landmark 2 sse for angle 57.0 = 86
# landmark 2 sse for angle 60.0 = 86
# landmark 2 sse for angle 63.0 = 89
# landmark 2 sse for angle 66.0 = 89
# landmark 2 sse for angle 69.0 = 89
# landmark 2 sse for angle 72.0 = 87
# landmark 2 sse for angle 75.0 = 84
# landmark 2 sse for angle 78.0 = 85
# landmark 2 sse for angle 81.0 = 85
# landmark 2 sse for angle 84.0 = 83
# landmark 2 sse for angle 87.0 = 81
# landmark 2 sse for angle 90.0 = 81
# landmark 2 sse for angle 93.0 = 81
# landmark 2 sse for angle 96.0 = 75
# landmark 2 sse for angle 99.0 = 74
# landmark 2 sse for angle 102.0 = 75
# landmark 2 sse for angle 105.0 = 70
# landmark 2 sse for angle 108.0 = 71
# landmark 2 sse for angle 111.0 = 73
# landmark 2 sse for angle 114.0 = 74
# landmark 2 sse for angle 117.0 = 75
# landmark 2 sse for angle 120.0 = 76
# landmark 2 sse for angle 123.0 = 77
# landmark 2 sse for angle 126.0 = 77
# landmark 2 sse for angle 129.0 = 79
# landmark 2 sse for angle 132.0 = 81
# landmark 2 sse for angle 135.0 = 82
# landmark 2 sse for angle 138.0 = 85
# landmark 2 sse for angle 141.0 = 86
# landmark 2 sse for angle 144.0 = 87
# landmark 2 sse for angle 147.0 = 89
# landmark 2 sse for angle 150.0 = 90
# landmark 2 sse for angle 153.0 = 89
# landmark 2 sse for angle 156.0 = 90
# landmark 2 sse for angle 159.0 = 93
# landmark 2 sse for angle 162.0 = 93
# landmark 2 sse for angle 165.0 = 96
# landmark 2 sse for angle 168.0 = 97
# landmark 2 sse for angle 171.0 = 97
# landmark 2 sse for angle 174.0 = 97
# landmark 2 sse for angle 177.0 = 98
# landmark 2 sse for angle 180.0 = 99
# landmark 2 sse for angle 183.0 = 98
# landmark 2 sse for angle 186.0 = 97
# landmark 2 sse for angle 189.0 = 95
# landmark 2 sse for angle 192.0 = 96
# landmark 2 sse for angle 195.0 = 96
# landmark 2 sse for angle 198.0 = 98
# landmark 2 sse for angle 201.0 = 99
# landmark 2 sse for angle 204.0 = 99
# landmark 2 sse for angle 207.0 = 98
# landmark 2 sse for angle 210.0 = 98
# landmark 2 sse for angle 213.0 = 96
# landmark 2 sse for angle 216.0 = 95
# landmark 2 sse for angle 219.0 = 93
# landmark 2 sse for angle 222.0 = 94
# landmark 2 sse for angle 225.0 = 94
# landmark 2 sse for angle 228.0 = 93
# landmark 2 sse for angle 231.0 = 93
# landmark 2 sse for angle 234.0 = 93
# landmark 2 sse for angle 237.0 = 93
# landmark 2 sse for angle 240.0 = 93
# landmark 2 sse for angle 243.0 = 93
# landmark 2 sse for angle 246.0 = 93
# landmark 2 sse for angle 249.0 = 93
# landmark 2 sse for angle 252.0 = 91
# landmark 2 sse for angle 255.0 = 91
# landmark 2 sse for angle 258.0 = 89
# landmark 2 sse for angle 261.0 = 87
# landmark 2 sse for angle 264.0 = 85
# landmark 2 sse for angle 267.0 = 82
# landmark 2 sse for angle 270.0 = 78
# landmark 2 sse for angle 273.0 = 74
# landmark 2 sse for angle 276.0 = 74
# landmark 2 sse for angle 279.0 = 72
# landmark 2 sse for angle 282.0 = 68
# landmark 2 sse for angle 285.0 = 65
# landmark 2 sse for angle 288.0 = 69
# landmark 2 sse for angle 291.0 = 74
# landmark 2 sse for angle 294.0 = 76
# landmark 2 sse for angle 297.0 = 76
# landmark 2 sse for angle 300.0 = 80
# landmark 2 sse for angle 303.0 = 79
# landmark 2 sse for angle 306.0 = 81
# landmark 2 sse for angle 309.0 = 81
# landmark 2 sse for angle 312.0 = 83
# landmark 2 sse for angle 315.0 = 81
# landmark 2 sse for angle 318.0 = 79
# landmark 2 sse for angle 321.0 = 79
# landmark 2 sse for angle 324.0 = 80
# landmark 2 sse for angle 327.0 = 82
# landmark 2 sse for angle 330.0 = 82
# landmark 2 sse for angle 333.0 = 84
# landmark 2 sse for angle 336.0 = 81
# landmark 2 sse for angle 339.0 = 80
# landmark 2 sse for angle 342.0 = 81
# landmark 2 sse for angle 345.0 = 78
# landmark 2 sse for angle 348.0 = 78
# landmark 2 sse for angle 351.0 = 79
# landmark 2 sse for angle 354.0 = 77
# landmark 2 sse for angle 357.0 = 72
# true landmark = 1, landmark predicted = 1, true angle = -76.38444961552014, predicted angle = -74.99999999999996
# -------------------------
# min error for landmark 1 = 54
# landmark 2 sse for angle 0.0 = 90
# landmark 2 sse for angle 3.0 = 90
# landmark 2 sse for angle 6.0 = 90
# landmark 2 sse for angle 9.0 = 90
# landmark 2 sse for angle 12.0 = 91
# landmark 2 sse for angle 15.0 = 90
# landmark 2 sse for angle 18.0 = 90
# landmark 2 sse for angle 21.0 = 90
# landmark 2 sse for angle 24.0 = 88
# landmark 2 sse for angle 27.0 = 89
# landmark 2 sse for angle 30.0 = 88
# landmark 2 sse for angle 33.0 = 88
# landmark 2 sse for angle 36.0 = 87
# landmark 2 sse for angle 39.0 = 85
# landmark 2 sse for angle 42.0 = 85
# landmark 2 sse for angle 45.0 = 85
# landmark 2 sse for angle 48.0 = 86
# landmark 2 sse for angle 51.0 = 84
# landmark 2 sse for angle 54.0 = 86
# landmark 2 sse for angle 57.0 = 86
# landmark 2 sse for angle 60.0 = 86
# landmark 2 sse for angle 63.0 = 84
# landmark 2 sse for angle 66.0 = 83
# landmark 2 sse for angle 69.0 = 82
# landmark 2 sse for angle 72.0 = 80
# landmark 2 sse for angle 75.0 = 80
# landmark 2 sse for angle 78.0 = 80
# landmark 2 sse for angle 81.0 = 74
# landmark 2 sse for angle 84.0 = 75
# landmark 2 sse for angle 87.0 = 76
# landmark 2 sse for angle 90.0 = 77
# landmark 2 sse for angle 93.0 = 80
# landmark 2 sse for angle 96.0 = 81
# landmark 2 sse for angle 99.0 = 78
# landmark 2 sse for angle 102.0 = 78
# landmark 2 sse for angle 105.0 = 77
# landmark 2 sse for angle 108.0 = 74
# landmark 2 sse for angle 111.0 = 76
# landmark 2 sse for angle 114.0 = 75
# landmark 2 sse for angle 117.0 = 76
# landmark 2 sse for angle 120.0 = 75
# landmark 2 sse for angle 123.0 = 74
# landmark 2 sse for angle 126.0 = 73
# landmark 2 sse for angle 129.0 = 71
# landmark 2 sse for angle 132.0 = 70
# landmark 2 sse for angle 135.0 = 68
# landmark 2 sse for angle 138.0 = 66
# landmark 2 sse for angle 141.0 = 66
# landmark 2 sse for angle 144.0 = 64
# landmark 2 sse for angle 147.0 = 62
# landmark 2 sse for angle 150.0 = 60
# landmark 2 sse for angle 153.0 = 57
# landmark 2 sse for angle 156.0 = 50
# min error for landmark 2 = 54
# true landmark = 2, landmark predicted = 2, true angle = 165.6723024832883, predicted angle = 164.99999999999997
# -------------------------
# true landmark = 3, landmark predicted = 3, true angle = -121.26773772532069, predicted angle = -120.00000000000001
# -------------------------
# true landmark = 4, landmark predicted = 4, true angle = -86.4220993418349, predicted angle = -86.99999999999997
# -------------------------
# true landmark = 0, landmark predicted = 0, true angle = 30.294105740441395, predicted angle = 29.999999999999996
# -------------------------
# min error for landmark 1 = 36
# landmark 2 sse for angle 0.0 = 83
# landmark 2 sse for angle 3.0 = 82
# landmark 2 sse for angle 6.0 = 85
# landmark 2 sse for angle 9.0 = 87
# landmark 2 sse for angle 12.0 = 87
# landmark 2 sse for angle 15.0 = 83
# landmark 2 sse for angle 18.0 = 82
# landmark 2 sse for angle 21.0 = 84
# landmark 2 sse for angle 24.0 = 83
# landmark 2 sse for angle 27.0 = 83
# landmark 2 sse for angle 30.0 = 82
# landmark 2 sse for angle 33.0 = 79
# landmark 2 sse for angle 36.0 = 74
# landmark 2 sse for angle 39.0 = 72
# landmark 2 sse for angle 42.0 = 71
# landmark 2 sse for angle 45.0 = 71
# landmark 2 sse for angle 48.0 = 72
# landmark 2 sse for angle 51.0 = 74
# landmark 2 sse for angle 54.0 = 77
# landmark 2 sse for angle 57.0 = 81
# landmark 2 sse for angle 60.0 = 82
# landmark 2 sse for angle 63.0 = 85
# landmark 2 sse for angle 66.0 = 83
# landmark 2 sse for angle 69.0 = 84
# landmark 2 sse for angle 72.0 = 86
# landmark 2 sse for angle 75.0 = 87
# landmark 2 sse for angle 78.0 = 88
# landmark 2 sse for angle 81.0 = 88
# landmark 2 sse for angle 84.0 = 87
# landmark 2 sse for angle 87.0 = 87
# landmark 2 sse for angle 90.0 = 88
# landmark 2 sse for angle 93.0 = 90
# landmark 2 sse for angle 96.0 = 91
# landmark 2 sse for angle 99.0 = 93
# landmark 2 sse for angle 102.0 = 96
# landmark 2 sse for angle 105.0 = 97
# landmark 2 sse for angle 108.0 = 100
# landmark 2 sse for angle 111.0 = 100
# landmark 2 sse for angle 114.0 = 99
# landmark 2 sse for angle 117.0 = 98
# landmark 2 sse for angle 120.0 = 97
# landmark 2 sse for angle 123.0 = 98
# landmark 2 sse for angle 126.0 = 99
# landmark 2 sse for angle 129.0 = 98
# landmark 2 sse for angle 132.0 = 98
# landmark 2 sse for angle 135.0 = 99
# landmark 2 sse for angle 138.0 = 100
# landmark 2 sse for angle 141.0 = 99
# landmark 2 sse for angle 144.0 = 98
# landmark 2 sse for angle 147.0 = 99
# landmark 2 sse for angle 150.0 = 95
# landmark 2 sse for angle 153.0 = 96
# landmark 2 sse for angle 156.0 = 95
# landmark 2 sse for angle 159.0 = 95
# landmark 2 sse for angle 162.0 = 93
# landmark 2 sse for angle 165.0 = 93
# landmark 2 sse for angle 168.0 = 92
# landmark 2 sse for angle 171.0 = 92
# landmark 2 sse for angle 174.0 = 94
# landmark 2 sse for angle 177.0 = 93
# landmark 2 sse for angle 180.0 = 90
# landmark 2 sse for angle 183.0 = 93
# landmark 2 sse for angle 186.0 = 94
# landmark 2 sse for angle 189.0 = 92
# landmark 2 sse for angle 192.0 = 92
# landmark 2 sse for angle 195.0 = 93
# landmark 2 sse for angle 198.0 = 93
# landmark 2 sse for angle 201.0 = 94
# landmark 2 sse for angle 204.0 = 93
# landmark 2 sse for angle 207.0 = 91
# landmark 2 sse for angle 210.0 = 92
# landmark 2 sse for angle 213.0 = 82
# landmark 2 sse for angle 216.0 = 75
# landmark 2 sse for angle 219.0 = 75
# landmark 2 sse for angle 222.0 = 72
# landmark 2 sse for angle 225.0 = 71
# landmark 2 sse for angle 228.0 = 75
# landmark 2 sse for angle 231.0 = 76
# landmark 2 sse for angle 234.0 = 74
# landmark 2 sse for angle 237.0 = 76
# landmark 2 sse for angle 240.0 = 79
# landmark 2 sse for angle 243.0 = 78
# landmark 2 sse for angle 246.0 = 78
# landmark 2 sse for angle 249.0 = 80
# landmark 2 sse for angle 252.0 = 80
# landmark 2 sse for angle 255.0 = 83
# landmark 2 sse for angle 258.0 = 80
# landmark 2 sse for angle 261.0 = 78
# landmark 2 sse for angle 264.0 = 81
# landmark 2 sse for angle 267.0 = 81
# landmark 2 sse for angle 270.0 = 79
# landmark 2 sse for angle 273.0 = 78
# landmark 2 sse for angle 276.0 = 78
# landmark 2 sse for angle 279.0 = 77
# landmark 2 sse for angle 282.0 = 82
# landmark 2 sse for angle 285.0 = 80
# landmark 2 sse for angle 288.0 = 78
# landmark 2 sse for angle 291.0 = 79
# landmark 2 sse for angle 294.0 = 79
# landmark 2 sse for angle 297.0 = 78
# landmark 2 sse for angle 300.0 = 78
# landmark 2 sse for angle 303.0 = 72
# landmark 2 sse for angle 306.0 = 71
# landmark 2 sse for angle 309.0 = 66
# landmark 2 sse for angle 312.0 = 64
# landmark 2 sse for angle 315.0 = 63
# landmark 2 sse for angle 318.0 = 67
# landmark 2 sse for angle 321.0 = 67
# landmark 2 sse for angle 324.0 = 73
# landmark 2 sse for angle 327.0 = 73
# landmark 2 sse for angle 330.0 = 73
# landmark 2 sse for angle 333.0 = 78
# landmark 2 sse for angle 336.0 = 79
# landmark 2 sse for angle 339.0 = 80
# landmark 2 sse for angle 342.0 = 82
# landmark 2 sse for angle 345.0 = 83
# landmark 2 sse for angle 348.0 = 81
# landmark 2 sse for angle 351.0 = 79
# landmark 2 sse for angle 354.0 = 83
# landmark 2 sse for angle 357.0 = 82
# true landmark = 1, landmark predicted = 1, true angle = -133.8230538815112, predicted angle = -135.0
# -------------------------
# min error for landmark 1 = 52
# landmark 2 sse for angle 0.0 = 74
# landmark 2 sse for angle 3.0 = 75
# landmark 2 sse for angle 6.0 = 72
# landmark 2 sse for angle 9.0 = 74
# landmark 2 sse for angle 12.0 = 73
# landmark 2 sse for angle 15.0 = 70
# landmark 2 sse for angle 18.0 = 68
# landmark 2 sse for angle 21.0 = 67
# landmark 2 sse for angle 24.0 = 58
# landmark 2 sse for angle 27.0 = 56
# landmark 2 sse for angle 30.0 = 53
# landmark 2 sse for angle 33.0 = 44
# min error for landmark 2 = 52
# true landmark = 2, landmark predicted = 2, true angle = 41.07905682098261, predicted angle = 42.0
# -------------------------
# true landmark = 3, landmark predicted = 3, true angle = 93.4849481491665, predicted angle = 92.99999999999999
# -------------------------
# true landmark = 4, landmark predicted = 4, true angle = -13.888069236295518, predicted angle = -14.999999999999982
# -------------------------
# true landmark = 0, landmark predicted = 0, true angle = -65.76048305453665, predicted angle = -65.99999999999997
# -------------------------
# min error for landmark 1 = 24
# landmark 2 sse for angle 0.0 = 61
# landmark 2 sse for angle 3.0 = 59
# landmark 2 sse for angle 6.0 = 60
# landmark 2 sse for angle 9.0 = 59
# landmark 2 sse for angle 12.0 = 61
# landmark 2 sse for angle 15.0 = 62
# landmark 2 sse for angle 18.0 = 61
# landmark 2 sse for angle 21.0 = 64
# landmark 2 sse for angle 24.0 = 64
# landmark 2 sse for angle 27.0 = 66
# landmark 2 sse for angle 30.0 = 68
# landmark 2 sse for angle 33.0 = 70
# landmark 2 sse for angle 36.0 = 69
# landmark 2 sse for angle 39.0 = 70
# landmark 2 sse for angle 42.0 = 72
# landmark 2 sse for angle 45.0 = 73
# landmark 2 sse for angle 48.0 = 72
# landmark 2 sse for angle 51.0 = 71
# landmark 2 sse for angle 54.0 = 72
# landmark 2 sse for angle 57.0 = 73
# landmark 2 sse for angle 60.0 = 74
# landmark 2 sse for angle 63.0 = 76
# landmark 2 sse for angle 66.0 = 78
# landmark 2 sse for angle 69.0 = 78
# landmark 2 sse for angle 72.0 = 79
# landmark 2 sse for angle 75.0 = 80
# landmark 2 sse for angle 78.0 = 81
# landmark 2 sse for angle 81.0 = 82
# landmark 2 sse for angle 84.0 = 82
# landmark 2 sse for angle 87.0 = 82
# landmark 2 sse for angle 90.0 = 83
# landmark 2 sse for angle 93.0 = 82
# landmark 2 sse for angle 96.0 = 82
# landmark 2 sse for angle 99.0 = 82
# landmark 2 sse for angle 102.0 = 82
# landmark 2 sse for angle 105.0 = 83
# landmark 2 sse for angle 108.0 = 82
# landmark 2 sse for angle 111.0 = 81
# landmark 2 sse for angle 114.0 = 81
# landmark 2 sse for angle 117.0 = 79
# landmark 2 sse for angle 120.0 = 79
# landmark 2 sse for angle 123.0 = 79
# landmark 2 sse for angle 126.0 = 79
# landmark 2 sse for angle 129.0 = 78
# landmark 2 sse for angle 132.0 = 76
# landmark 2 sse for angle 135.0 = 77
# landmark 2 sse for angle 138.0 = 76
# landmark 2 sse for angle 141.0 = 77
# landmark 2 sse for angle 144.0 = 76
# landmark 2 sse for angle 147.0 = 78
# landmark 2 sse for angle 150.0 = 79
# landmark 2 sse for angle 153.0 = 79
# landmark 2 sse for angle 156.0 = 79
# landmark 2 sse for angle 159.0 = 76
# landmark 2 sse for angle 162.0 = 76
# landmark 2 sse for angle 165.0 = 76
# landmark 2 sse for angle 168.0 = 77
# landmark 2 sse for angle 171.0 = 76
# landmark 2 sse for angle 174.0 = 72
# landmark 2 sse for angle 177.0 = 70
# landmark 2 sse for angle 180.0 = 67
# landmark 2 sse for angle 183.0 = 66
# landmark 2 sse for angle 186.0 = 61
# landmark 2 sse for angle 189.0 = 56
# landmark 2 sse for angle 192.0 = 55
# landmark 2 sse for angle 195.0 = 57
# landmark 2 sse for angle 198.0 = 59
# landmark 2 sse for angle 201.0 = 58
# landmark 2 sse for angle 204.0 = 58
# landmark 2 sse for angle 207.0 = 61
# landmark 2 sse for angle 210.0 = 63
# landmark 2 sse for angle 213.0 = 65
# landmark 2 sse for angle 216.0 = 67
# landmark 2 sse for angle 219.0 = 65
# landmark 2 sse for angle 222.0 = 65
# landmark 2 sse for angle 225.0 = 66
# landmark 2 sse for angle 228.0 = 66
# landmark 2 sse for angle 231.0 = 65
# landmark 2 sse for angle 234.0 = 67
# landmark 2 sse for angle 237.0 = 68
# landmark 2 sse for angle 240.0 = 64
# landmark 2 sse for angle 243.0 = 64
# landmark 2 sse for angle 246.0 = 63
# landmark 2 sse for angle 249.0 = 62
# landmark 2 sse for angle 252.0 = 61
# landmark 2 sse for angle 255.0 = 58
# landmark 2 sse for angle 258.0 = 59
# landmark 2 sse for angle 261.0 = 60
# landmark 2 sse for angle 264.0 = 57
# landmark 2 sse for angle 267.0 = 57
# landmark 2 sse for angle 270.0 = 54
# landmark 2 sse for angle 273.0 = 51
# landmark 2 sse for angle 276.0 = 46
# landmark 2 sse for angle 279.0 = 44
# landmark 2 sse for angle 282.0 = 46
# landmark 2 sse for angle 285.0 = 48
# landmark 2 sse for angle 288.0 = 51
# landmark 2 sse for angle 291.0 = 53
# landmark 2 sse for angle 294.0 = 53
# landmark 2 sse for angle 297.0 = 58
# landmark 2 sse for angle 300.0 = 58
# landmark 2 sse for angle 303.0 = 60
# landmark 2 sse for angle 306.0 = 60
# landmark 2 sse for angle 309.0 = 60
# landmark 2 sse for angle 312.0 = 61
# landmark 2 sse for angle 315.0 = 62
# landmark 2 sse for angle 318.0 = 62
# landmark 2 sse for angle 321.0 = 62
# landmark 2 sse for angle 324.0 = 65
# landmark 2 sse for angle 327.0 = 63
# landmark 2 sse for angle 330.0 = 63
# landmark 2 sse for angle 333.0 = 64
# landmark 2 sse for angle 336.0 = 65
# landmark 2 sse for angle 339.0 = 64
# landmark 2 sse for angle 342.0 = 64
# landmark 2 sse for angle 345.0 = 62
# landmark 2 sse for angle 348.0 = 62
# landmark 2 sse for angle 351.0 = 63
# landmark 2 sse for angle 354.0 = 62
# landmark 2 sse for angle 357.0 = 61
# true landmark = 1, landmark predicted = 1, true angle = -169.33109262816268, predicted angle = -171.0
# -------------------------
# min error for landmark 1 = 50
# landmark 2 sse for angle 0.0 = 76
# landmark 2 sse for angle 3.0 = 77
# landmark 2 sse for angle 6.0 = 78
# landmark 2 sse for angle 9.0 = 80
# landmark 2 sse for angle 12.0 = 83
# landmark 2 sse for angle 15.0 = 83
# landmark 2 sse for angle 18.0 = 84
# landmark 2 sse for angle 21.0 = 84
# landmark 2 sse for angle 24.0 = 86
# landmark 2 sse for angle 27.0 = 89
# landmark 2 sse for angle 30.0 = 89
# landmark 2 sse for angle 33.0 = 92
# landmark 2 sse for angle 36.0 = 92
# landmark 2 sse for angle 39.0 = 93
# landmark 2 sse for angle 42.0 = 94
# landmark 2 sse for angle 45.0 = 95
# landmark 2 sse for angle 48.0 = 95
# landmark 2 sse for angle 51.0 = 96
# landmark 2 sse for angle 54.0 = 96
# landmark 2 sse for angle 57.0 = 96
# landmark 2 sse for angle 60.0 = 97
# landmark 2 sse for angle 63.0 = 98
# landmark 2 sse for angle 66.0 = 97
# landmark 2 sse for angle 69.0 = 98
# landmark 2 sse for angle 72.0 = 97
# landmark 2 sse for angle 75.0 = 97
# landmark 2 sse for angle 78.0 = 98
# landmark 2 sse for angle 81.0 = 99
# landmark 2 sse for angle 84.0 = 99
# landmark 2 sse for angle 87.0 = 98
# landmark 2 sse for angle 90.0 = 98
# landmark 2 sse for angle 93.0 = 98
# landmark 2 sse for angle 96.0 = 97
# landmark 2 sse for angle 99.0 = 95
# landmark 2 sse for angle 102.0 = 95
# landmark 2 sse for angle 105.0 = 94
# landmark 2 sse for angle 108.0 = 94
# landmark 2 sse for angle 111.0 = 94
# landmark 2 sse for angle 114.0 = 94
# landmark 2 sse for angle 117.0 = 94
# landmark 2 sse for angle 120.0 = 94
# landmark 2 sse for angle 123.0 = 94
# landmark 2 sse for angle 126.0 = 94
# landmark 2 sse for angle 129.0 = 94
# landmark 2 sse for angle 132.0 = 92
# landmark 2 sse for angle 135.0 = 92
# landmark 2 sse for angle 138.0 = 92
# landmark 2 sse for angle 141.0 = 92
# landmark 2 sse for angle 144.0 = 92
# landmark 2 sse for angle 147.0 = 91
# landmark 2 sse for angle 150.0 = 92
# landmark 2 sse for angle 153.0 = 91
# landmark 2 sse for angle 156.0 = 90
# landmark 2 sse for angle 159.0 = 90
# landmark 2 sse for angle 162.0 = 88
# landmark 2 sse for angle 165.0 = 89
# landmark 2 sse for angle 168.0 = 91
# landmark 2 sse for angle 171.0 = 88
# landmark 2 sse for angle 174.0 = 86
# landmark 2 sse for angle 177.0 = 81
# landmark 2 sse for angle 180.0 = 78
# landmark 2 sse for angle 183.0 = 78
# landmark 2 sse for angle 186.0 = 77
# landmark 2 sse for angle 189.0 = 78
# landmark 2 sse for angle 192.0 = 82
# landmark 2 sse for angle 195.0 = 82
# landmark 2 sse for angle 198.0 = 81
# landmark 2 sse for angle 201.0 = 82
# landmark 2 sse for angle 204.0 = 82
# landmark 2 sse for angle 207.0 = 79
# landmark 2 sse for angle 210.0 = 81
# landmark 2 sse for angle 213.0 = 78
# landmark 2 sse for angle 216.0 = 78
# landmark 2 sse for angle 219.0 = 76
# landmark 2 sse for angle 222.0 = 76
# landmark 2 sse for angle 225.0 = 75
# landmark 2 sse for angle 228.0 = 76
# landmark 2 sse for angle 231.0 = 75
# landmark 2 sse for angle 234.0 = 74
# landmark 2 sse for angle 237.0 = 74
# landmark 2 sse for angle 240.0 = 74
# landmark 2 sse for angle 243.0 = 71
# landmark 2 sse for angle 246.0 = 69
# landmark 2 sse for angle 249.0 = 63
# landmark 2 sse for angle 252.0 = 59
# landmark 2 sse for angle 255.0 = 58
# landmark 2 sse for angle 258.0 = 56
# landmark 2 sse for angle 261.0 = 52
# landmark 2 sse for angle 264.0 = 51
# landmark 2 sse for angle 267.0 = 40
# min error for landmark 2 = 50
# true landmark = 2, landmark predicted = 2, true angle = -87.78706348983042, predicted angle = -90.0
# -------------------------
# true landmark = 3, landmark predicted = 3, true angle = 75.80934194935658, predicted angle = 75.00000000000001
# -------------------------
# true landmark = 4, landmark predicted = 4, true angle = 157.68069469855362, predicted angle = 159.0
# -------------------------
# true landmark = 0, landmark predicted = 0, true angle = -129.17782653735952, predicted angle = -128.99999999999997
# -------------------------
# min error for landmark 1 = 27
# landmark 2 sse for angle 0.0 = 88
# landmark 2 sse for angle 3.0 = 87
# landmark 2 sse for angle 6.0 = 88
# landmark 2 sse for angle 9.0 = 88
# landmark 2 sse for angle 12.0 = 88
# landmark 2 sse for angle 15.0 = 88
# landmark 2 sse for angle 18.0 = 90
# landmark 2 sse for angle 21.0 = 92
# landmark 2 sse for angle 24.0 = 94
# landmark 2 sse for angle 27.0 = 93
# landmark 2 sse for angle 30.0 = 94
# landmark 2 sse for angle 33.0 = 95
# landmark 2 sse for angle 36.0 = 95
# landmark 2 sse for angle 39.0 = 95
# landmark 2 sse for angle 42.0 = 96
# landmark 2 sse for angle 45.0 = 96
# landmark 2 sse for angle 48.0 = 96
# landmark 2 sse for angle 51.0 = 96
# landmark 2 sse for angle 54.0 = 93
# landmark 2 sse for angle 57.0 = 95
# landmark 2 sse for angle 60.0 = 95
# landmark 2 sse for angle 63.0 = 95
# landmark 2 sse for angle 66.0 = 95
# landmark 2 sse for angle 69.0 = 95
# landmark 2 sse for angle 72.0 = 94
# landmark 2 sse for angle 75.0 = 94
# landmark 2 sse for angle 78.0 = 94
# landmark 2 sse for angle 81.0 = 95
# landmark 2 sse for angle 84.0 = 94
# landmark 2 sse for angle 87.0 = 92
# landmark 2 sse for angle 90.0 = 91
# landmark 2 sse for angle 93.0 = 91
# landmark 2 sse for angle 96.0 = 90
# landmark 2 sse for angle 99.0 = 90
# landmark 2 sse for angle 102.0 = 91
# landmark 2 sse for angle 105.0 = 90
# landmark 2 sse for angle 108.0 = 87
# landmark 2 sse for angle 111.0 = 88
# landmark 2 sse for angle 114.0 = 88
# landmark 2 sse for angle 117.0 = 88
# landmark 2 sse for angle 120.0 = 88
# landmark 2 sse for angle 123.0 = 87
# landmark 2 sse for angle 126.0 = 86
# landmark 2 sse for angle 129.0 = 85
# landmark 2 sse for angle 132.0 = 84
# landmark 2 sse for angle 135.0 = 82
# landmark 2 sse for angle 138.0 = 78
# landmark 2 sse for angle 141.0 = 74
# landmark 2 sse for angle 144.0 = 70
# landmark 2 sse for angle 147.0 = 69
# landmark 2 sse for angle 150.0 = 63
# landmark 2 sse for angle 153.0 = 60
# landmark 2 sse for angle 156.0 = 68
# landmark 2 sse for angle 159.0 = 70
# landmark 2 sse for angle 162.0 = 71
# landmark 2 sse for angle 165.0 = 74
# landmark 2 sse for angle 168.0 = 70
# landmark 2 sse for angle 171.0 = 75
# landmark 2 sse for angle 174.0 = 76
# landmark 2 sse for angle 177.0 = 78
# landmark 2 sse for angle 180.0 = 79
# landmark 2 sse for angle 183.0 = 77
# landmark 2 sse for angle 186.0 = 75
# landmark 2 sse for angle 189.0 = 78
# landmark 2 sse for angle 192.0 = 79
# landmark 2 sse for angle 195.0 = 78
# landmark 2 sse for angle 198.0 = 75
# landmark 2 sse for angle 201.0 = 75
# landmark 2 sse for angle 204.0 = 74
# landmark 2 sse for angle 207.0 = 74
# landmark 2 sse for angle 210.0 = 75
# landmark 2 sse for angle 213.0 = 72
# landmark 2 sse for angle 216.0 = 69
# landmark 2 sse for angle 219.0 = 67
# landmark 2 sse for angle 222.0 = 63
# landmark 2 sse for angle 225.0 = 64
# landmark 2 sse for angle 228.0 = 68
# landmark 2 sse for angle 231.0 = 66
# landmark 2 sse for angle 234.0 = 63
# landmark 2 sse for angle 237.0 = 62
# landmark 2 sse for angle 240.0 = 63
# landmark 2 sse for angle 243.0 = 64
# landmark 2 sse for angle 246.0 = 70
# landmark 2 sse for angle 249.0 = 72
# landmark 2 sse for angle 252.0 = 75
# landmark 2 sse for angle 255.0 = 77
# landmark 2 sse for angle 258.0 = 79
# landmark 2 sse for angle 261.0 = 82
# landmark 2 sse for angle 264.0 = 81
# landmark 2 sse for angle 267.0 = 83
# landmark 2 sse for angle 270.0 = 84
# landmark 2 sse for angle 273.0 = 84
# landmark 2 sse for angle 276.0 = 84
# landmark 2 sse for angle 279.0 = 87
# landmark 2 sse for angle 282.0 = 89
# landmark 2 sse for angle 285.0 = 88
# landmark 2 sse for angle 288.0 = 87
# landmark 2 sse for angle 291.0 = 86
# landmark 2 sse for angle 294.0 = 86
# landmark 2 sse for angle 297.0 = 85
# landmark 2 sse for angle 300.0 = 83
# landmark 2 sse for angle 303.0 = 84
# landmark 2 sse for angle 306.0 = 82
# landmark 2 sse for angle 309.0 = 81
# landmark 2 sse for angle 312.0 = 79
# landmark 2 sse for angle 315.0 = 79
# landmark 2 sse for angle 318.0 = 76
# landmark 2 sse for angle 321.0 = 74
# landmark 2 sse for angle 324.0 = 73
# landmark 2 sse for angle 327.0 = 72
# landmark 2 sse for angle 330.0 = 73
# landmark 2 sse for angle 333.0 = 75
# landmark 2 sse for angle 336.0 = 77
# landmark 2 sse for angle 339.0 = 80
# landmark 2 sse for angle 342.0 = 82
# landmark 2 sse for angle 345.0 = 84
# landmark 2 sse for angle 348.0 = 84
# landmark 2 sse for angle 351.0 = 85
# landmark 2 sse for angle 354.0 = 86
# landmark 2 sse for angle 357.0 = 86
# true landmark = 1, landmark predicted = 1, true angle = 151.65508920750221, predicted angle = 153.0
# -------------------------
# min error for landmark 1 = 55
# landmark 2 sse for angle 0.0 = 88
# landmark 2 sse for angle 3.0 = 88
# landmark 2 sse for angle 6.0 = 88
# landmark 2 sse for angle 9.0 = 88
# landmark 2 sse for angle 12.0 = 87
# landmark 2 sse for angle 15.0 = 86
# landmark 2 sse for angle 18.0 = 86
# landmark 2 sse for angle 21.0 = 85
# landmark 2 sse for angle 24.0 = 81
# landmark 2 sse for angle 27.0 = 78
# landmark 2 sse for angle 30.0 = 77
# landmark 2 sse for angle 33.0 = 77
# landmark 2 sse for angle 36.0 = 76
# landmark 2 sse for angle 39.0 = 78
# landmark 2 sse for angle 42.0 = 77
# landmark 2 sse for angle 45.0 = 77
# landmark 2 sse for angle 48.0 = 78
# landmark 2 sse for angle 51.0 = 78
# landmark 2 sse for angle 54.0 = 78
# landmark 2 sse for angle 57.0 = 80
# landmark 2 sse for angle 60.0 = 80
# landmark 2 sse for angle 63.0 = 79
# landmark 2 sse for angle 66.0 = 82
# landmark 2 sse for angle 69.0 = 84
# landmark 2 sse for angle 72.0 = 84
# landmark 2 sse for angle 75.0 = 81
# landmark 2 sse for angle 78.0 = 82
# landmark 2 sse for angle 81.0 = 75
# landmark 2 sse for angle 84.0 = 77
# landmark 2 sse for angle 87.0 = 74
# landmark 2 sse for angle 90.0 = 71
# landmark 2 sse for angle 93.0 = 69
# landmark 2 sse for angle 96.0 = 69
# landmark 2 sse for angle 99.0 = 69
# landmark 2 sse for angle 102.0 = 66
# landmark 2 sse for angle 105.0 = 65
# landmark 2 sse for angle 108.0 = 61
# landmark 2 sse for angle 111.0 = 58
# landmark 2 sse for angle 114.0 = 50
# min error for landmark 2 = 55
# true landmark = 2, landmark predicted = 2, true angle = 125.43346223506566, predicted angle = 126.0
# -------------------------
# true landmark = 3, landmark predicted = 3, true angle = -30.576325828535033, predicted angle = -30.000000000000014
# -------------------------
# true landmark = 4, landmark predicted = 4, true angle = -88.6164825064094, predicted angle = -86.99999999999997
# -------------------------
# /vol/bitbucket/wbai/virt/computer_vision_ubuntu18.04/lib/python3.6/site-packages/matplotlib/pyplot.py:513: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# true landmark = 0, landmark predicted = 0, true angle = -83.12107609734971, predicted angle = -84.00000000000003
# -------------------------
# true landmark = 1, landmark predicted = 4, true angle = -135.68833548647532, predicted angle = -57.000000000000014
# -------------------------
# min error for landmark 1 = 54
# landmark 2 sse for angle 0.0 = 84
# landmark 2 sse for angle 3.0 = 84
# landmark 2 sse for angle 6.0 = 83
# landmark 2 sse for angle 9.0 = 83
# landmark 2 sse for angle 12.0 = 79
# landmark 2 sse for angle 15.0 = 78
# landmark 2 sse for angle 18.0 = 79
# landmark 2 sse for angle 21.0 = 79
# landmark 2 sse for angle 24.0 = 79
# landmark 2 sse for angle 27.0 = 80
# landmark 2 sse for angle 30.0 = 79
# landmark 2 sse for angle 33.0 = 78
# landmark 2 sse for angle 36.0 = 75
# landmark 2 sse for angle 39.0 = 73
# landmark 2 sse for angle 42.0 = 73
# landmark 2 sse for angle 45.0 = 70
# landmark 2 sse for angle 48.0 = 68
# landmark 2 sse for angle 51.0 = 63
# landmark 2 sse for angle 54.0 = 59
# landmark 2 sse for angle 57.0 = 51
# min error for landmark 2 = 54
# true landmark = 2, landmark predicted = 2, true angle = 70.27456828972329, predicted angle = 68.99999999999999
# -------------------------
# true landmark = 3, landmark predicted = 3, true angle = -61.54628905593104, predicted angle = -59.999999999999986
# -------------------------
# true landmark = 4, landmark predicted = 4, true angle = 44.88188655460348, predicted angle = 45.0
# -------------------------
# true landmark = 0, landmark predicted = 0, true angle = -134.42559368319434, predicted angle = -135.0
# -------------------------
# min error for landmark 1 = 23
# landmark 2 sse for angle 0.0 = 69
# landmark 2 sse for angle 3.0 = 71
# landmark 2 sse for angle 6.0 = 74
# landmark 2 sse for angle 9.0 = 74
# landmark 2 sse for angle 12.0 = 75
# landmark 2 sse for angle 15.0 = 75
# landmark 2 sse for angle 18.0 = 75
# landmark 2 sse for angle 21.0 = 74
# landmark 2 sse for angle 24.0 = 72
# landmark 2 sse for angle 27.0 = 73
# landmark 2 sse for angle 30.0 = 73
# landmark 2 sse for angle 33.0 = 74
# landmark 2 sse for angle 36.0 = 75
# landmark 2 sse for angle 39.0 = 73
# landmark 2 sse for angle 42.0 = 72
# landmark 2 sse for angle 45.0 = 70
# landmark 2 sse for angle 48.0 = 68
# landmark 2 sse for angle 51.0 = 66
# landmark 2 sse for angle 54.0 = 65
# landmark 2 sse for angle 57.0 = 61
# landmark 2 sse for angle 60.0 = 60
# landmark 2 sse for angle 63.0 = 59
# landmark 2 sse for angle 66.0 = 59
# landmark 2 sse for angle 69.0 = 58
# landmark 2 sse for angle 72.0 = 62
# landmark 2 sse for angle 75.0 = 65
# landmark 2 sse for angle 78.0 = 65
# landmark 2 sse for angle 81.0 = 66
# landmark 2 sse for angle 84.0 = 67
# landmark 2 sse for angle 87.0 = 68
# landmark 2 sse for angle 90.0 = 71
# landmark 2 sse for angle 93.0 = 72
# landmark 2 sse for angle 96.0 = 72
# landmark 2 sse for angle 99.0 = 70
# landmark 2 sse for angle 102.0 = 72
# landmark 2 sse for angle 105.0 = 75
# landmark 2 sse for angle 108.0 = 77
# landmark 2 sse for angle 111.0 = 76
# landmark 2 sse for angle 114.0 = 78
# landmark 2 sse for angle 117.0 = 80
# landmark 2 sse for angle 120.0 = 79
# landmark 2 sse for angle 123.0 = 80
# landmark 2 sse for angle 126.0 = 82
# landmark 2 sse for angle 129.0 = 83
# landmark 2 sse for angle 132.0 = 83
# landmark 2 sse for angle 135.0 = 85
# landmark 2 sse for angle 138.0 = 84
# landmark 2 sse for angle 141.0 = 84
# landmark 2 sse for angle 144.0 = 85
# landmark 2 sse for angle 147.0 = 86
# landmark 2 sse for angle 150.0 = 87
# landmark 2 sse for angle 153.0 = 86
# landmark 2 sse for angle 156.0 = 87
# landmark 2 sse for angle 159.0 = 87
# landmark 2 sse for angle 162.0 = 86
# landmark 2 sse for angle 165.0 = 86
# landmark 2 sse for angle 168.0 = 86
# landmark 2 sse for angle 171.0 = 86
# landmark 2 sse for angle 174.0 = 85
# landmark 2 sse for angle 177.0 = 85
# landmark 2 sse for angle 180.0 = 86
# landmark 2 sse for angle 183.0 = 87
# landmark 2 sse for angle 186.0 = 86
# landmark 2 sse for angle 189.0 = 85
# landmark 2 sse for angle 192.0 = 86
# landmark 2 sse for angle 195.0 = 85
# landmark 2 sse for angle 198.0 = 84
# landmark 2 sse for angle 201.0 = 82
# landmark 2 sse for angle 204.0 = 81
# landmark 2 sse for angle 207.0 = 83
# landmark 2 sse for angle 210.0 = 83
# landmark 2 sse for angle 213.0 = 81
# landmark 2 sse for angle 216.0 = 81
# landmark 2 sse for angle 219.0 = 79
# landmark 2 sse for angle 222.0 = 78
# landmark 2 sse for angle 225.0 = 78
# landmark 2 sse for angle 228.0 = 77
# landmark 2 sse for angle 231.0 = 76
# landmark 2 sse for angle 234.0 = 75
# landmark 2 sse for angle 237.0 = 73
# landmark 2 sse for angle 240.0 = 74
# landmark 2 sse for angle 243.0 = 71
# landmark 2 sse for angle 246.0 = 66
# landmark 2 sse for angle 249.0 = 61
# landmark 2 sse for angle 252.0 = 60
# landmark 2 sse for angle 255.0 = 64
# landmark 2 sse for angle 258.0 = 64
# landmark 2 sse for angle 261.0 = 67
# landmark 2 sse for angle 264.0 = 69
# landmark 2 sse for angle 267.0 = 66
# landmark 2 sse for angle 270.0 = 68
# landmark 2 sse for angle 273.0 = 69
# landmark 2 sse for angle 276.0 = 73
# landmark 2 sse for angle 279.0 = 72
# landmark 2 sse for angle 282.0 = 71
# landmark 2 sse for angle 285.0 = 72
# landmark 2 sse for angle 288.0 = 70
# landmark 2 sse for angle 291.0 = 69
# landmark 2 sse for angle 294.0 = 68
# landmark 2 sse for angle 297.0 = 68
# landmark 2 sse for angle 300.0 = 68
# landmark 2 sse for angle 303.0 = 66
# landmark 2 sse for angle 306.0 = 65
# landmark 2 sse for angle 309.0 = 63
# landmark 2 sse for angle 312.0 = 64
# landmark 2 sse for angle 315.0 = 64
# landmark 2 sse for angle 318.0 = 61
# landmark 2 sse for angle 321.0 = 59
# landmark 2 sse for angle 324.0 = 58
# landmark 2 sse for angle 327.0 = 60
# landmark 2 sse for angle 330.0 = 60
# landmark 2 sse for angle 333.0 = 57
# landmark 2 sse for angle 336.0 = 52
# landmark 2 sse for angle 339.0 = 54
# landmark 2 sse for angle 342.0 = 55
# landmark 2 sse for angle 345.0 = 58
# landmark 2 sse for angle 348.0 = 60
# landmark 2 sse for angle 351.0 = 63
# landmark 2 sse for angle 354.0 = 65
# landmark 2 sse for angle 357.0 = 67
# true landmark = 1, landmark predicted = 1, true angle = -108.31704359057336, predicted angle = -108.0
# -------------------------
# min error for landmark 1 = 51
# landmark 2 sse for angle 0.0 = 76
# landmark 2 sse for angle 3.0 = 75
# landmark 2 sse for angle 6.0 = 79
# landmark 2 sse for angle 9.0 = 81
# landmark 2 sse for angle 12.0 = 85
# landmark 2 sse for angle 15.0 = 82
# landmark 2 sse for angle 18.0 = 81
# landmark 2 sse for angle 21.0 = 82
# landmark 2 sse for angle 24.0 = 85
# landmark 2 sse for angle 27.0 = 85
# landmark 2 sse for angle 30.0 = 83
# landmark 2 sse for angle 33.0 = 83
# landmark 2 sse for angle 36.0 = 83
# landmark 2 sse for angle 39.0 = 81
# landmark 2 sse for angle 42.0 = 81
# landmark 2 sse for angle 45.0 = 82
# landmark 2 sse for angle 48.0 = 84
# landmark 2 sse for angle 51.0 = 85
# landmark 2 sse for angle 54.0 = 85
# landmark 2 sse for angle 57.0 = 86
# landmark 2 sse for angle 60.0 = 87
# landmark 2 sse for angle 63.0 = 87
# landmark 2 sse for angle 66.0 = 87
# landmark 2 sse for angle 69.0 = 87
# landmark 2 sse for angle 72.0 = 87
# landmark 2 sse for angle 75.0 = 88
# landmark 2 sse for angle 78.0 = 89
# landmark 2 sse for angle 81.0 = 90
# landmark 2 sse for angle 84.0 = 91
# landmark 2 sse for angle 87.0 = 92
# landmark 2 sse for angle 90.0 = 93
# landmark 2 sse for angle 93.0 = 94
# landmark 2 sse for angle 96.0 = 95
# landmark 2 sse for angle 99.0 = 96
# landmark 2 sse for angle 102.0 = 97
# landmark 2 sse for angle 105.0 = 97
# landmark 2 sse for angle 108.0 = 97
# landmark 2 sse for angle 111.0 = 97
# landmark 2 sse for angle 114.0 = 97
# landmark 2 sse for angle 117.0 = 98
# landmark 2 sse for angle 120.0 = 98
# landmark 2 sse for angle 123.0 = 98
# landmark 2 sse for angle 126.0 = 98
# landmark 2 sse for angle 129.0 = 98
# landmark 2 sse for angle 132.0 = 99
# landmark 2 sse for angle 135.0 = 99
# landmark 2 sse for angle 138.0 = 99
# landmark 2 sse for angle 141.0 = 99
# landmark 2 sse for angle 144.0 = 97
# landmark 2 sse for angle 147.0 = 97
# landmark 2 sse for angle 150.0 = 97
# landmark 2 sse for angle 153.0 = 96
# landmark 2 sse for angle 156.0 = 96
# landmark 2 sse for angle 159.0 = 95
# landmark 2 sse for angle 162.0 = 95
# landmark 2 sse for angle 165.0 = 95
# landmark 2 sse for angle 168.0 = 95
# landmark 2 sse for angle 171.0 = 94
# landmark 2 sse for angle 174.0 = 94
# landmark 2 sse for angle 177.0 = 94
# landmark 2 sse for angle 180.0 = 94
# landmark 2 sse for angle 183.0 = 94
# landmark 2 sse for angle 186.0 = 92
# landmark 2 sse for angle 189.0 = 91
# landmark 2 sse for angle 192.0 = 92
# landmark 2 sse for angle 195.0 = 91
# landmark 2 sse for angle 198.0 = 92
# landmark 2 sse for angle 201.0 = 91
# landmark 2 sse for angle 204.0 = 91
# landmark 2 sse for angle 207.0 = 89
# landmark 2 sse for angle 210.0 = 88
# landmark 2 sse for angle 213.0 = 86
# landmark 2 sse for angle 216.0 = 85
# landmark 2 sse for angle 219.0 = 85
# landmark 2 sse for angle 222.0 = 84
# landmark 2 sse for angle 225.0 = 84
# landmark 2 sse for angle 228.0 = 84
# landmark 2 sse for angle 231.0 = 85
# landmark 2 sse for angle 234.0 = 84
# landmark 2 sse for angle 237.0 = 84
# landmark 2 sse for angle 240.0 = 81
# landmark 2 sse for angle 243.0 = 81
# landmark 2 sse for angle 246.0 = 85
# landmark 2 sse for angle 249.0 = 82
# landmark 2 sse for angle 252.0 = 82
# landmark 2 sse for angle 255.0 = 79
# landmark 2 sse for angle 258.0 = 79
# landmark 2 sse for angle 261.0 = 79
# landmark 2 sse for angle 264.0 = 77
# landmark 2 sse for angle 267.0 = 75
# landmark 2 sse for angle 270.0 = 79
# landmark 2 sse for angle 273.0 = 76
# landmark 2 sse for angle 276.0 = 76
# landmark 2 sse for angle 279.0 = 74
# landmark 2 sse for angle 282.0 = 74
# landmark 2 sse for angle 285.0 = 69
# landmark 2 sse for angle 288.0 = 69
# landmark 2 sse for angle 291.0 = 67
# landmark 2 sse for angle 294.0 = 68
# landmark 2 sse for angle 297.0 = 60
# landmark 2 sse for angle 300.0 = 55
# landmark 2 sse for angle 303.0 = 44
# min error for landmark 2 = 51
# true landmark = 2, landmark predicted = 2, true angle = -49.68263523665701, predicted angle = -48.00000000000002
# -------------------------
# true landmark = 3, landmark predicted = 3, true angle = 79.73442736916073, predicted angle = 81.0
# -------------------------
# true landmark = 4, landmark predicted = 4, true angle = 29.119468450794038, predicted angle = 29.999999999999996
# -------------------------
# true landmark = 0, landmark predicted = 0, true angle = -63.91737467516623, predicted angle = -63.0
# -------------------------
# min error for landmark 1 = 17
# landmark 2 sse for angle 0.0 = 74
# landmark 2 sse for angle 3.0 = 72
# landmark 2 sse for angle 6.0 = 72
# landmark 2 sse for angle 9.0 = 72
# landmark 2 sse for angle 12.0 = 71
# landmark 2 sse for angle 15.0 = 72
# landmark 2 sse for angle 18.0 = 71
# landmark 2 sse for angle 21.0 = 73
# landmark 2 sse for angle 24.0 = 75
# landmark 2 sse for angle 27.0 = 76
# landmark 2 sse for angle 30.0 = 75
# landmark 2 sse for angle 33.0 = 74
# landmark 2 sse for angle 36.0 = 73
# landmark 2 sse for angle 39.0 = 72
# landmark 2 sse for angle 42.0 = 71
# landmark 2 sse for angle 45.0 = 72
# landmark 2 sse for angle 48.0 = 71
# landmark 2 sse for angle 51.0 = 71
# landmark 2 sse for angle 54.0 = 67
# landmark 2 sse for angle 57.0 = 65
# landmark 2 sse for angle 60.0 = 64
# landmark 2 sse for angle 63.0 = 64
# landmark 2 sse for angle 66.0 = 63
# landmark 2 sse for angle 69.0 = 57
# landmark 2 sse for angle 72.0 = 54
# landmark 2 sse for angle 75.0 = 56
# landmark 2 sse for angle 78.0 = 59
# landmark 2 sse for angle 81.0 = 63
# landmark 2 sse for angle 84.0 = 62
# landmark 2 sse for angle 87.0 = 64
# landmark 2 sse for angle 90.0 = 66
# landmark 2 sse for angle 93.0 = 68
# landmark 2 sse for angle 96.0 = 69
# landmark 2 sse for angle 99.0 = 70
# landmark 2 sse for angle 102.0 = 72
# landmark 2 sse for angle 105.0 = 75
# landmark 2 sse for angle 108.0 = 74
# landmark 2 sse for angle 111.0 = 75
# landmark 2 sse for angle 114.0 = 78
# landmark 2 sse for angle 117.0 = 78
# landmark 2 sse for angle 120.0 = 81
# landmark 2 sse for angle 123.0 = 81
# landmark 2 sse for angle 126.0 = 82
# landmark 2 sse for angle 129.0 = 82
# landmark 2 sse for angle 132.0 = 82
# landmark 2 sse for angle 135.0 = 81
# landmark 2 sse for angle 138.0 = 81
# landmark 2 sse for angle 141.0 = 81
# landmark 2 sse for angle 144.0 = 76
# landmark 2 sse for angle 147.0 = 69
# landmark 2 sse for angle 150.0 = 69
# landmark 2 sse for angle 153.0 = 69
# landmark 2 sse for angle 156.0 = 69
# landmark 2 sse for angle 159.0 = 66
# landmark 2 sse for angle 162.0 = 65
# landmark 2 sse for angle 165.0 = 65
# landmark 2 sse for angle 168.0 = 65
# landmark 2 sse for angle 171.0 = 67
# landmark 2 sse for angle 174.0 = 70
# landmark 2 sse for angle 177.0 = 71
# landmark 2 sse for angle 180.0 = 72
# landmark 2 sse for angle 183.0 = 74
# landmark 2 sse for angle 186.0 = 74
# landmark 2 sse for angle 189.0 = 77
# landmark 2 sse for angle 192.0 = 79
# landmark 2 sse for angle 195.0 = 79
# landmark 2 sse for angle 198.0 = 79
# landmark 2 sse for angle 201.0 = 81
# landmark 2 sse for angle 204.0 = 82
# landmark 2 sse for angle 207.0 = 84
# landmark 2 sse for angle 210.0 = 86
# landmark 2 sse for angle 213.0 = 88
# landmark 2 sse for angle 216.0 = 89
# landmark 2 sse for angle 219.0 = 89
# landmark 2 sse for angle 222.0 = 91
# landmark 2 sse for angle 225.0 = 92
# landmark 2 sse for angle 228.0 = 92
# landmark 2 sse for angle 231.0 = 92
# landmark 2 sse for angle 234.0 = 92
# landmark 2 sse for angle 237.0 = 92
# landmark 2 sse for angle 240.0 = 91
# landmark 2 sse for angle 243.0 = 92
# landmark 2 sse for angle 246.0 = 92
# landmark 2 sse for angle 249.0 = 91
# landmark 2 sse for angle 252.0 = 92
# landmark 2 sse for angle 255.0 = 92
# landmark 2 sse for angle 258.0 = 91
# landmark 2 sse for angle 261.0 = 91
# landmark 2 sse for angle 264.0 = 92
# landmark 2 sse for angle 267.0 = 92
# landmark 2 sse for angle 270.0 = 91
# landmark 2 sse for angle 273.0 = 88
# landmark 2 sse for angle 276.0 = 87
# landmark 2 sse for angle 279.0 = 86
# landmark 2 sse for angle 282.0 = 85
# landmark 2 sse for angle 285.0 = 86
# landmark 2 sse for angle 288.0 = 85
# landmark 2 sse for angle 291.0 = 85
# landmark 2 sse for angle 294.0 = 86
# landmark 2 sse for angle 297.0 = 86
# landmark 2 sse for angle 300.0 = 85
# landmark 2 sse for angle 303.0 = 83
# landmark 2 sse for angle 306.0 = 83
# landmark 2 sse for angle 309.0 = 81
# landmark 2 sse for angle 312.0 = 81
# landmark 2 sse for angle 315.0 = 81
# landmark 2 sse for angle 318.0 = 80
# landmark 2 sse for angle 321.0 = 79
# landmark 2 sse for angle 324.0 = 76
# landmark 2 sse for angle 327.0 = 75
# landmark 2 sse for angle 330.0 = 71
# landmark 2 sse for angle 333.0 = 72
# landmark 2 sse for angle 336.0 = 71
# landmark 2 sse for angle 339.0 = 66
# landmark 2 sse for angle 342.0 = 62
# landmark 2 sse for angle 345.0 = 62
# landmark 2 sse for angle 348.0 = 70
# landmark 2 sse for angle 351.0 = 73
# landmark 2 sse for angle 354.0 = 71
# landmark 2 sse for angle 357.0 = 73
# true landmark = 1, landmark predicted = 1, true angle = -15.662159427398924, predicted angle = -14.999999999999982
# -------------------------
# min error for landmark 1 = 45
# landmark 2 sse for angle 0.0 = 77
# landmark 2 sse for angle 3.0 = 76
# landmark 2 sse for angle 6.0 = 76
# landmark 2 sse for angle 9.0 = 76
# landmark 2 sse for angle 12.0 = 74
# landmark 2 sse for angle 15.0 = 75
# landmark 2 sse for angle 18.0 = 75
# landmark 2 sse for angle 21.0 = 76
# landmark 2 sse for angle 24.0 = 75
# landmark 2 sse for angle 27.0 = 73
# landmark 2 sse for angle 30.0 = 75
# landmark 2 sse for angle 33.0 = 71
# landmark 2 sse for angle 36.0 = 70
# landmark 2 sse for angle 39.0 = 68
# landmark 2 sse for angle 42.0 = 67
# landmark 2 sse for angle 45.0 = 66
# landmark 2 sse for angle 48.0 = 62
# landmark 2 sse for angle 51.0 = 58
# landmark 2 sse for angle 54.0 = 57
# landmark 2 sse for angle 57.0 = 52
# landmark 2 sse for angle 60.0 = 51
# landmark 2 sse for angle 63.0 = 46
# landmark 2 sse for angle 66.0 = 30
# min error for landmark 2 = 45
# true landmark = 2, landmark predicted = 2, true angle = 69.83193425776294, predicted angle = 68.99999999999999
# -------------------------
# true landmark = 3, landmark predicted = 3, true angle = 93.991359482544, predicted angle = 92.99999999999999
# -------------------------
# true landmark = 4, landmark predicted = 4, true angle = -130.08281081537945, predicted angle = -128.99999999999997
# -------------------------
# true landmark = 0, landmark predicted = 0, true angle = -105.6232550120296, predicted angle = -104.99999999999999
# -------------------------
# min error for landmark 1 = 21
# landmark 2 sse for angle 0.0 = 91
# landmark 2 sse for angle 3.0 = 92
# landmark 2 sse for angle 6.0 = 91
# landmark 2 sse for angle 9.0 = 91
# landmark 2 sse for angle 12.0 = 90
# landmark 2 sse for angle 15.0 = 88
# landmark 2 sse for angle 18.0 = 89
# landmark 2 sse for angle 21.0 = 89
# landmark 2 sse for angle 24.0 = 88
# landmark 2 sse for angle 27.0 = 88
# landmark 2 sse for angle 30.0 = 83
# landmark 2 sse for angle 33.0 = 80
# landmark 2 sse for angle 36.0 = 75
# landmark 2 sse for angle 39.0 = 71
# landmark 2 sse for angle 42.0 = 67
# landmark 2 sse for angle 45.0 = 61
# landmark 2 sse for angle 48.0 = 62
# landmark 2 sse for angle 51.0 = 71
# landmark 2 sse for angle 54.0 = 72
# landmark 2 sse for angle 57.0 = 75
# landmark 2 sse for angle 60.0 = 77
# landmark 2 sse for angle 63.0 = 76
# landmark 2 sse for angle 66.0 = 76
# landmark 2 sse for angle 69.0 = 75
# landmark 2 sse for angle 72.0 = 75
# landmark 2 sse for angle 75.0 = 78
# landmark 2 sse for angle 78.0 = 79
# landmark 2 sse for angle 81.0 = 79
# landmark 2 sse for angle 84.0 = 76
# landmark 2 sse for angle 87.0 = 77
# landmark 2 sse for angle 90.0 = 78
# landmark 2 sse for angle 93.0 = 77
# landmark 2 sse for angle 96.0 = 76
# landmark 2 sse for angle 99.0 = 75
# landmark 2 sse for angle 102.0 = 74
# landmark 2 sse for angle 105.0 = 71
# landmark 2 sse for angle 108.0 = 76
# landmark 2 sse for angle 111.0 = 75
# landmark 2 sse for angle 114.0 = 75
# landmark 2 sse for angle 117.0 = 76
# landmark 2 sse for angle 120.0 = 72
# landmark 2 sse for angle 123.0 = 67
# landmark 2 sse for angle 126.0 = 63
# landmark 2 sse for angle 129.0 = 57
# landmark 2 sse for angle 132.0 = 59
# landmark 2 sse for angle 135.0 = 54
# landmark 2 sse for angle 138.0 = 57
# landmark 2 sse for angle 141.0 = 60
# landmark 2 sse for angle 144.0 = 63
# landmark 2 sse for angle 147.0 = 64
# landmark 2 sse for angle 150.0 = 66
# landmark 2 sse for angle 153.0 = 66
# landmark 2 sse for angle 156.0 = 69
# landmark 2 sse for angle 159.0 = 71
# landmark 2 sse for angle 162.0 = 74
# landmark 2 sse for angle 165.0 = 74
# landmark 2 sse for angle 168.0 = 75
# landmark 2 sse for angle 171.0 = 76
# landmark 2 sse for angle 174.0 = 76
# landmark 2 sse for angle 177.0 = 75
# landmark 2 sse for angle 180.0 = 79
# landmark 2 sse for angle 183.0 = 79
# landmark 2 sse for angle 186.0 = 80
# landmark 2 sse for angle 189.0 = 79
# landmark 2 sse for angle 192.0 = 80
# landmark 2 sse for angle 195.0 = 78
# landmark 2 sse for angle 198.0 = 79
# landmark 2 sse for angle 201.0 = 80
# landmark 2 sse for angle 204.0 = 79
# landmark 2 sse for angle 207.0 = 78
# landmark 2 sse for angle 210.0 = 76
# landmark 2 sse for angle 213.0 = 74
# landmark 2 sse for angle 216.0 = 69
# landmark 2 sse for angle 219.0 = 68
# landmark 2 sse for angle 222.0 = 67
# landmark 2 sse for angle 225.0 = 68
# landmark 2 sse for angle 228.0 = 68
# landmark 2 sse for angle 231.0 = 71
# landmark 2 sse for angle 234.0 = 71
# landmark 2 sse for angle 237.0 = 74
# landmark 2 sse for angle 240.0 = 77
# landmark 2 sse for angle 243.0 = 78
# landmark 2 sse for angle 246.0 = 76
# landmark 2 sse for angle 249.0 = 77
# landmark 2 sse for angle 252.0 = 77
# landmark 2 sse for angle 255.0 = 77
# landmark 2 sse for angle 258.0 = 76
# landmark 2 sse for angle 261.0 = 79
# landmark 2 sse for angle 264.0 = 80
# landmark 2 sse for angle 267.0 = 83
# landmark 2 sse for angle 270.0 = 84
# landmark 2 sse for angle 273.0 = 86
# landmark 2 sse for angle 276.0 = 89
# landmark 2 sse for angle 279.0 = 89
# landmark 2 sse for angle 282.0 = 89
# landmark 2 sse for angle 285.0 = 93
# landmark 2 sse for angle 288.0 = 94
# landmark 2 sse for angle 291.0 = 94
# landmark 2 sse for angle 294.0 = 95
# landmark 2 sse for angle 297.0 = 95
# landmark 2 sse for angle 300.0 = 96
# landmark 2 sse for angle 303.0 = 96
# landmark 2 sse for angle 306.0 = 98
# landmark 2 sse for angle 309.0 = 98
# landmark 2 sse for angle 312.0 = 98
# landmark 2 sse for angle 315.0 = 96
# landmark 2 sse for angle 318.0 = 96
# landmark 2 sse for angle 321.0 = 96
# landmark 2 sse for angle 324.0 = 96
# landmark 2 sse for angle 327.0 = 97
# landmark 2 sse for angle 330.0 = 98
# landmark 2 sse for angle 333.0 = 98
# landmark 2 sse for angle 336.0 = 95
# landmark 2 sse for angle 339.0 = 94
# landmark 2 sse for angle 342.0 = 94
# landmark 2 sse for angle 345.0 = 92
# landmark 2 sse for angle 348.0 = 89
# landmark 2 sse for angle 351.0 = 92
# landmark 2 sse for angle 354.0 = 91
# landmark 2 sse for angle 357.0 = 92
# true landmark = 1, landmark predicted = 1, true angle = 46.59134026017236, predicted angle = 45.0
# -------------------------
# min error for landmark 1 = 57
# ...
# landmark 2 sse for angle 156.0 = 78
# landmark 2 sse for angle 159.0 = 78
# landmark 2 sse for angle 162.0 = 79
# landmark 2 sse for angle 165.0 = 79
# landmark 2 sse for angle 168.0 = 75
# landmark 2 sse for angle 171.0 = 75
# landmark 2 sse for angle 174.0 = 75
# landmark 2 sse for angle 177.0 = 73
# landmark 2 sse for angle 180.0 = 70
# landmark 2 sse for angle 183.0 = 65
# landmark 2 sse for angle 186.0 = 62
# landmark 2 sse for angle 189.0 = 55
# landmark 2 sse for angle 192.0 = 51
# min error for landmark 2 = 53
# true landmark = 2, landmark predicted = 2, true angle = -150.8666799961112, predicted angle = -149.99999999999997
# -------------------------
# true landmark = 3, landmark predicted = 3, true angle = -70.31149934558846, predicted angle = -69.00000000000004
# -------------------------
# true landmark = 4, landmark predicted = 4, true angle = -61.96046686937068, predicted angle = -59.999999999999986
# -------------------------
# true landmark = 0, landmark predicted = 0, true angle = -141.18355340959013, predicted angle = -141.0
# -------------------------
# min error for landmark 1 = 19
# landmark 2 sse for angle 0.0 = 76
# landmark 2 sse for angle 3.0 = 71
# landmark 2 sse for angle 6.0 = 73
# landmark 2 sse for angle 9.0 = 75
# landmark 2 sse for angle 12.0 = 76
# landmark 2 sse for angle 15.0 = 76
# landmark 2 sse for angle 18.0 = 73
# landmark 2 sse for angle 21.0 = 73
# landmark 2 sse for angle 24.0 = 73
# landmark 2 sse for angle 27.0 = 76
# landmark 2 sse for angle 30.0 = 75
# landmark 2 sse for angle 33.0 = 74
# landmark 2 sse for angle 36.0 = 75
# landmark 2 sse for angle 39.0 = 72
# landmark 2 sse for angle 42.0 = 73
# landmark 2 sse for angle 45.0 = 71
# landmark 2 sse for angle 48.0 = 71
# landmark 2 sse for angle 51.0 = 64
# landmark 2 sse for angle 54.0 = 62
# landmark 2 sse for angle 57.0 = 59
# landmark 2 sse for angle 60.0 = 58
# landmark 2 sse for angle 63.0 = 57
# landmark 2 sse for angle 66.0 = 64
# landmark 2 sse for angle 69.0 = 65
# landmark 2 sse for angle 72.0 = 68
# landmark 2 sse for angle 75.0 = 71
# landmark 2 sse for angle 78.0 = 73
# landmark 2 sse for angle 81.0 = 76
# landmark 2 sse for angle 84.0 = 80
# landmark 2 sse for angle 87.0 = 79
# landmark 2 sse for angle 90.0 = 81
# landmark 2 sse for angle 93.0 = 78
# landmark 2 sse for angle 96.0 = 81
# landmark 2 sse for angle 99.0 = 81
# landmark 2 sse for angle 102.0 = 83
# landmark 2 sse for angle 105.0 = 86
# landmark 2 sse for angle 108.0 = 85
# landmark 2 sse for angle 111.0 = 86
# landmark 2 sse for angle 114.0 = 84
# landmark 2 sse for angle 117.0 = 84
# landmark 2 sse for angle 120.0 = 86
# landmark 2 sse for angle 123.0 = 86
# landmark 2 sse for angle 126.0 = 85
# landmark 2 sse for angle 129.0 = 83
# landmark 2 sse for angle 132.0 = 82
# landmark 2 sse for angle 135.0 = 79
# landmark 2 sse for angle 138.0 = 80
# landmark 2 sse for angle 141.0 = 77
# landmark 2 sse for angle 144.0 = 73
# landmark 2 sse for angle 147.0 = 72
# landmark 2 sse for angle 150.0 = 71
# landmark 2 sse for angle 153.0 = 72
# landmark 2 sse for angle 156.0 = 74
# landmark 2 sse for angle 159.0 = 75
# landmark 2 sse for angle 162.0 = 76
# landmark 2 sse for angle 165.0 = 78
# landmark 2 sse for angle 168.0 = 77
# landmark 2 sse for angle 171.0 = 81
# landmark 2 sse for angle 174.0 = 85
# landmark 2 sse for angle 177.0 = 88
# landmark 2 sse for angle 180.0 = 88
# landmark 2 sse for angle 183.0 = 86
# landmark 2 sse for angle 186.0 = 88
# landmark 2 sse for angle 189.0 = 91
# landmark 2 sse for angle 192.0 = 93
# landmark 2 sse for angle 195.0 = 93
# landmark 2 sse for angle 198.0 = 90
# landmark 2 sse for angle 201.0 = 92
# landmark 2 sse for angle 204.0 = 94
# landmark 2 sse for angle 207.0 = 96
# landmark 2 sse for angle 210.0 = 98
# landmark 2 sse for angle 213.0 = 97
# landmark 2 sse for angle 216.0 = 98
# landmark 2 sse for angle 219.0 = 98
# landmark 2 sse for angle 222.0 = 99
# landmark 2 sse for angle 225.0 = 99
# landmark 2 sse for angle 228.0 = 98
# landmark 2 sse for angle 231.0 = 98
# landmark 2 sse for angle 234.0 = 97
# landmark 2 sse for angle 237.0 = 100
# landmark 2 sse for angle 240.0 = 98
# landmark 2 sse for angle 243.0 = 97
# landmark 2 sse for angle 246.0 = 98
# landmark 2 sse for angle 249.0 = 96
# landmark 2 sse for angle 252.0 = 96
# landmark 2 sse for angle 255.0 = 97
# landmark 2 sse for angle 258.0 = 96
# landmark 2 sse for angle 261.0 = 93
# landmark 2 sse for angle 264.0 = 95
# landmark 2 sse for angle 267.0 = 93
# landmark 2 sse for angle 270.0 = 94
# landmark 2 sse for angle 273.0 = 92
# landmark 2 sse for angle 276.0 = 93
# landmark 2 sse for angle 279.0 = 92
# landmark 2 sse for angle 282.0 = 92
# landmark 2 sse for angle 285.0 = 92
# landmark 2 sse for angle 288.0 = 92
# landmark 2 sse for angle 291.0 = 91
# landmark 2 sse for angle 294.0 = 91
# landmark 2 sse for angle 297.0 = 91
# landmark 2 sse for angle 300.0 = 89
# landmark 2 sse for angle 303.0 = 87
# landmark 2 sse for angle 306.0 = 88
# landmark 2 sse for angle 309.0 = 88
# landmark 2 sse for angle 312.0 = 87
# landmark 2 sse for angle 315.0 = 86
# landmark 2 sse for angle 318.0 = 84
# landmark 2 sse for angle 321.0 = 78
# landmark 2 sse for angle 324.0 = 72
# landmark 2 sse for angle 327.0 = 63
# landmark 2 sse for angle 330.0 = 64
# landmark 2 sse for angle 333.0 = 65
# landmark 2 sse for angle 336.0 = 69
# landmark 2 sse for angle 339.0 = 71
# landmark 2 sse for angle 342.0 = 70
# landmark 2 sse for angle 345.0 = 72
# landmark 2 sse for angle 348.0 = 72
# landmark 2 sse for angle 351.0 = 71
# landmark 2 sse for angle 354.0 = 74
# landmark 2 sse for angle 357.0 = 74
# true landmark = 1, landmark predicted = 1, true angle = -30.071873479318864, predicted angle = -30.000000000000014
# -------------------------
# min error for landmark 1 = 49
# landmark 2 sse for angle 0.0 = 82
# landmark 2 sse for angle 3.0 = 84
# landmark 2 sse for angle 6.0 = 84
# landmark 2 sse for angle 9.0 = 84
# landmark 2 sse for angle 12.0 = 82
# landmark 2 sse for angle 15.0 = 83
# landmark 2 sse for angle 18.0 = 82
# landmark 2 sse for angle 21.0 = 82
# landmark 2 sse for angle 24.0 = 81
# landmark 2 sse for angle 27.0 = 80
# landmark 2 sse for angle 30.0 = 80
# landmark 2 sse for angle 33.0 = 81
# landmark 2 sse for angle 36.0 = 81
# landmark 2 sse for angle 39.0 = 80
# landmark 2 sse for angle 42.0 = 80
# landmark 2 sse for angle 45.0 = 82
# landmark 2 sse for angle 48.0 = 83
# landmark 2 sse for angle 51.0 = 83
# landmark 2 sse for angle 54.0 = 83
# landmark 2 sse for angle 57.0 = 83
# landmark 2 sse for angle 60.0 = 83
# landmark 2 sse for angle 63.0 = 83
# landmark 2 sse for angle 66.0 = 81
# landmark 2 sse for angle 69.0 = 80
# landmark 2 sse for angle 72.0 = 80
# landmark 2 sse for angle 75.0 = 79
# landmark 2 sse for angle 78.0 = 75
# landmark 2 sse for angle 81.0 = 72
# landmark 2 sse for angle 84.0 = 72
# landmark 2 sse for angle 87.0 = 71
# landmark 2 sse for angle 90.0 = 69
# landmark 2 sse for angle 93.0 = 69
# landmark 2 sse for angle 96.0 = 68
# landmark 2 sse for angle 99.0 = 68
# landmark 2 sse for angle 102.0 = 67
# landmark 2 sse for angle 105.0 = 68
# landmark 2 sse for angle 108.0 = 66
# landmark 2 sse for angle 111.0 = 66
# landmark 2 sse for angle 114.0 = 66
# landmark 2 sse for angle 117.0 = 66
# landmark 2 sse for angle 120.0 = 68
# landmark 2 sse for angle 123.0 = 70
# landmark 2 sse for angle 126.0 = 68
# landmark 2 sse for angle 129.0 = 67
# landmark 2 sse for angle 132.0 = 64
# landmark 2 sse for angle 135.0 = 66
# landmark 2 sse for angle 138.0 = 66
# landmark 2 sse for angle 141.0 = 67
# landmark 2 sse for angle 144.0 = 68
# landmark 2 sse for angle 147.0 = 66
# landmark 2 sse for angle 150.0 = 67
# landmark 2 sse for angle 153.0 = 68
# landmark 2 sse for angle 156.0 = 67
# landmark 2 sse for angle 159.0 = 65
# landmark 2 sse for angle 162.0 = 63
# landmark 2 sse for angle 165.0 = 62
# landmark 2 sse for angle 168.0 = 58
# landmark 2 sse for angle 171.0 = 57
# landmark 2 sse for angle 174.0 = 50
# landmark 2 sse for angle 177.0 = 44
# min error for landmark 2 = 49
# true landmark = 2, landmark predicted = 2, true angle = -176.17529145537037, predicted angle = -177.00000000000003
# -------------------------
# true landmark = 3, landmark predicted = 3, true angle = 116.77941087069875, predicted angle = 117.0
# -------------------------
# true landmark = 4, landmark predicted = 4, true angle = 155.53117573974734, predicted angle = 156.0
# -------------------------
# true landmark = 0, landmark predicted = 0, true angle = -85.64681708815206, predicted angle = -86.99999999999997
# -------------------------
# min error for landmark 1 = 19
# landmark 2 sse for angle 0.0 = 96
# landmark 2 sse for angle 3.0 = 96
# landmark 2 sse for angle 6.0 = 96
# landmark 2 sse for angle 9.0 = 96
# landmark 2 sse for angle 12.0 = 96
# landmark 2 sse for angle 15.0 = 96
# landmark 2 sse for angle 18.0 = 94
# landmark 2 sse for angle 21.0 = 94
# landmark 2 sse for angle 24.0 = 93
# landmark 2 sse for angle 27.0 = 92
# landmark 2 sse for angle 30.0 = 92
# landmark 2 sse for angle 33.0 = 93
# landmark 2 sse for angle 36.0 = 92
# landmark 2 sse for angle 39.0 = 93
# landmark 2 sse for angle 42.0 = 92
# landmark 2 sse for angle 45.0 = 92
# landmark 2 sse for angle 48.0 = 92
# landmark 2 sse for angle 51.0 = 94
# landmark 2 sse for angle 54.0 = 92
# landmark 2 sse for angle 57.0 = 91
# landmark 2 sse for angle 60.0 = 90
# landmark 2 sse for angle 63.0 = 89
# landmark 2 sse for angle 66.0 = 88
# landmark 2 sse for angle 69.0 = 86
# landmark 2 sse for angle 72.0 = 84
# landmark 2 sse for angle 75.0 = 83
# landmark 2 sse for angle 78.0 = 79
# landmark 2 sse for angle 81.0 = 76
# landmark 2 sse for angle 84.0 = 75
# landmark 2 sse for angle 87.0 = 72
# landmark 2 sse for angle 90.0 = 68
# landmark 2 sse for angle 93.0 = 65
# landmark 2 sse for angle 96.0 = 68
# landmark 2 sse for angle 99.0 = 74
# landmark 2 sse for angle 102.0 = 76
# landmark 2 sse for angle 105.0 = 78
# landmark 2 sse for angle 108.0 = 78
# landmark 2 sse for angle 111.0 = 79
# landmark 2 sse for angle 114.0 = 81
# landmark 2 sse for angle 117.0 = 77
# landmark 2 sse for angle 120.0 = 78
# landmark 2 sse for angle 123.0 = 82
# landmark 2 sse for angle 126.0 = 84
# landmark 2 sse for angle 129.0 = 84
# landmark 2 sse for angle 132.0 = 84
# landmark 2 sse for angle 135.0 = 82
# landmark 2 sse for angle 138.0 = 80
# landmark 2 sse for angle 141.0 = 80
# landmark 2 sse for angle 144.0 = 78
# landmark 2 sse for angle 147.0 = 76
# landmark 2 sse for angle 150.0 = 74
# landmark 2 sse for angle 153.0 = 71
# landmark 2 sse for angle 156.0 = 72
# landmark 2 sse for angle 159.0 = 72
# landmark 2 sse for angle 162.0 = 70
# landmark 2 sse for angle 165.0 = 68
# landmark 2 sse for angle 168.0 = 65
# landmark 2 sse for angle 171.0 = 65
# landmark 2 sse for angle 174.0 = 62
# landmark 2 sse for angle 177.0 = 63
# landmark 2 sse for angle 180.0 = 61
# landmark 2 sse for angle 183.0 = 61
# landmark 2 sse for angle 186.0 = 67
# landmark 2 sse for angle 189.0 = 68
# landmark 2 sse for angle 192.0 = 69
# landmark 2 sse for angle 195.0 = 74
# landmark 2 sse for angle 198.0 = 77
# landmark 2 sse for angle 201.0 = 80
# landmark 2 sse for angle 204.0 = 82
# landmark 2 sse for angle 207.0 = 83
# landmark 2 sse for angle 210.0 = 84
# landmark 2 sse for angle 213.0 = 86
# landmark 2 sse for angle 216.0 = 85
# landmark 2 sse for angle 219.0 = 86
# landmark 2 sse for angle 222.0 = 87
# landmark 2 sse for angle 225.0 = 85
# landmark 2 sse for angle 228.0 = 85
# landmark 2 sse for angle 231.0 = 86
# landmark 2 sse for angle 234.0 = 84
# landmark 2 sse for angle 237.0 = 84
# landmark 2 sse for angle 240.0 = 84
# landmark 2 sse for angle 243.0 = 83
# landmark 2 sse for angle 246.0 = 83
# landmark 2 sse for angle 249.0 = 81
# landmark 2 sse for angle 252.0 = 80
# landmark 2 sse for angle 255.0 = 82
# landmark 2 sse for angle 258.0 = 81
# landmark 2 sse for angle 261.0 = 79
# landmark 2 sse for angle 264.0 = 76
# landmark 2 sse for angle 267.0 = 77
# landmark 2 sse for angle 270.0 = 74
# landmark 2 sse for angle 273.0 = 74
# landmark 2 sse for angle 276.0 = 71
# landmark 2 sse for angle 279.0 = 73
# landmark 2 sse for angle 282.0 = 75
# landmark 2 sse for angle 285.0 = 77
# landmark 2 sse for angle 288.0 = 80
# landmark 2 sse for angle 291.0 = 81
# landmark 2 sse for angle 294.0 = 82
# landmark 2 sse for angle 297.0 = 85
# landmark 2 sse for angle 300.0 = 86
# landmark 2 sse for angle 303.0 = 86
# landmark 2 sse for angle 306.0 = 87
# landmark 2 sse for angle 309.0 = 86
# landmark 2 sse for angle 312.0 = 87
# landmark 2 sse for angle 315.0 = 88
# landmark 2 sse for angle 318.0 = 89
# landmark 2 sse for angle 321.0 = 89
# landmark 2 sse for angle 324.0 = 90
# landmark 2 sse for angle 327.0 = 91
# landmark 2 sse for angle 330.0 = 93
# landmark 2 sse for angle 333.0 = 96
# landmark 2 sse for angle 336.0 = 96
# landmark 2 sse for angle 339.0 = 98
# landmark 2 sse for angle 342.0 = 98
# landmark 2 sse for angle 345.0 = 96
# landmark 2 sse for angle 348.0 = 96
# landmark 2 sse for angle 351.0 = 95
# landmark 2 sse for angle 354.0 = 97
# landmark 2 sse for angle 357.0 = 96
# true landmark = 1, landmark predicted = 1, true angle = 92.63346152283776, predicted angle = 92.99999999999999
# -------------------------
# min error for landmark 1 = 47
# landmark 2 sse for angle 0.0 = 78
# landmark 2 sse for angle 3.0 = 78
# landmark 2 sse for angle 6.0 = 78
# landmark 2 sse for angle 9.0 = 79
# landmark 2 sse for angle 12.0 = 80
# landmark 2 sse for angle 15.0 = 79
# landmark 2 sse for angle 18.0 = 79
# landmark 2 sse for angle 21.0 = 80
# landmark 2 sse for angle 24.0 = 81
# landmark 2 sse for angle 27.0 = 83
# landmark 2 sse for angle 30.0 = 85
# landmark 2 sse for angle 33.0 = 87
# landmark 2 sse for angle 36.0 = 87
# landmark 2 sse for angle 39.0 = 87
# landmark 2 sse for angle 42.0 = 86
# landmark 2 sse for angle 45.0 = 86
# landmark 2 sse for angle 48.0 = 86
# landmark 2 sse for angle 51.0 = 86
# landmark 2 sse for angle 54.0 = 86
# landmark 2 sse for angle 57.0 = 85
# landmark 2 sse for angle 60.0 = 85
# landmark 2 sse for angle 63.0 = 85
# landmark 2 sse for angle 66.0 = 84
# landmark 2 sse for angle 69.0 = 84
# landmark 2 sse for angle 72.0 = 85
# landmark 2 sse for angle 75.0 = 84
# landmark 2 sse for angle 78.0 = 81
# landmark 2 sse for angle 81.0 = 81
# landmark 2 sse for angle 84.0 = 81
# landmark 2 sse for angle 87.0 = 81
# landmark 2 sse for angle 90.0 = 81
# landmark 2 sse for angle 93.0 = 81
# landmark 2 sse for angle 96.0 = 81
# landmark 2 sse for angle 99.0 = 79
# landmark 2 sse for angle 102.0 = 78
# landmark 2 sse for angle 105.0 = 77
# landmark 2 sse for angle 108.0 = 76
# landmark 2 sse for angle 111.0 = 76
# landmark 2 sse for angle 114.0 = 77
# landmark 2 sse for angle 117.0 = 78
# landmark 2 sse for angle 120.0 = 78
# landmark 2 sse for angle 123.0 = 78
# landmark 2 sse for angle 126.0 = 74
# landmark 2 sse for angle 129.0 = 76
# landmark 2 sse for angle 132.0 = 75
# landmark 2 sse for angle 135.0 = 74
# landmark 2 sse for angle 138.0 = 72
# landmark 2 sse for angle 141.0 = 72
# landmark 2 sse for angle 144.0 = 71
# landmark 2 sse for angle 147.0 = 70
# landmark 2 sse for angle 150.0 = 69
# landmark 2 sse for angle 153.0 = 69
# landmark 2 sse for angle 156.0 = 68
# landmark 2 sse for angle 159.0 = 69
# landmark 2 sse for angle 162.0 = 71
# landmark 2 sse for angle 165.0 = 71
# landmark 2 sse for angle 168.0 = 67
# landmark 2 sse for angle 171.0 = 65
# landmark 2 sse for angle 174.0 = 67
# landmark 2 sse for angle 177.0 = 68
# landmark 2 sse for angle 180.0 = 69
# landmark 2 sse for angle 183.0 = 68
# landmark 2 sse for angle 186.0 = 71
# landmark 2 sse for angle 189.0 = 68
# landmark 2 sse for angle 192.0 = 69
# landmark 2 sse for angle 195.0 = 68
# landmark 2 sse for angle 198.0 = 67
# landmark 2 sse for angle 201.0 = 65
# landmark 2 sse for angle 204.0 = 65
# landmark 2 sse for angle 207.0 = 63
# landmark 2 sse for angle 210.0 = 63
# landmark 2 sse for angle 213.0 = 58
# landmark 2 sse for angle 216.0 = 53
# landmark 2 sse for angle 219.0 = 53
# landmark 2 sse for angle 222.0 = 53
# landmark 2 sse for angle 225.0 = 52
# landmark 2 sse for angle 228.0 = 52
# landmark 2 sse for angle 231.0 = 49
# landmark 2 sse for angle 234.0 = 47
# landmark 2 sse for angle 237.0 = 42
# min error for landmark 2 = 47
# true landmark = 2, landmark predicted = 2, true angle = -117.82500591706284, predicted angle = -117.0
# -------------------------
# true landmark = 3, landmark predicted = 3, true angle = 104.4522509749929, predicted angle = 105.0
# -------------------------
# true landmark = 4, landmark predicted = 4, true angle = 97.54984137653396, predicted angle = 96.0
# -------------------------
# >>> angle accuracy = 97.0 %

# %%
confusion = confusion_matrix(y_true,y_pred)
plt.figure(figsize = (7,5))
plt.matshow(confusion)
plt.colorbar()

# %%
w.set_robot_at(138,54,-156.527*pi/180.0)

# %%
w.measure_around()

# %%
a = lm.ground_truth_measurements[3]

# %%
a

# %%
import numpy as np
np.roll(a,-68)

# %%
print(w.r.particle_cloud)

# %%
w.rotate_robot(pi*2.0/120)

# %%
print(w.r.particle_cloud)

# %%
w.measure_around()
