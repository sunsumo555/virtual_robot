# %%
import world
import matplotlib.pyplot as plt
from math import pi
# %matplotlib inline

# %% [markdown]
# # CW4

# %%
w = world.World()
w.draw_map()
w.draw_particles()
plt.imshow(w.display)

# %%
for j in range(4):
    for i in range(4):
        w.move_robot_forward(10)

    w.rotate_robot(pi/2.0)

# %% [markdown]
# # CW5

# %%
w = world.World()
w.draw_map()
w.draw_particles()
plt.imshow(w.display)

# %%
w.move_robot_to(84,30)
w.move_robot_to(180,30)
w.move_robot_to(180,54)
w.move_robot_to(138,54)
w.move_robot_to(138,168)
w.move_robot_to(114,168)
w.move_robot_to(114,84)
w.move_robot_to(84,84)
w.move_robot_to(84,30)

# %%
w = world.World()
w.draw_map()
w.draw_particles()
plt.imshow(w.display)

# %%
w.move_robot_to_slam(84,30)
w.move_robot_to_slam(180,30)
w.move_robot_to_slam(180,54)
w.move_robot_to_slam(138,54)
w.move_robot_to_slam(138,168)
w.move_robot_to_slam(114,168)
w.move_robot_to_slam(114,84)
w.move_robot_to_slam(84,84)
w.move_robot_to_slam(84,30)
# Out:
# world: distance = 89.19641248391103
# destination at 84, 30
# robot at x = 9.55654284384192, y = 3.3878258016148397 theta = 19.41876994582186
# world: distance = 79.05717000327004
# destination at 84, 30
# robot at x = 18.869048941765623, y = 6.729111182219705 theta = 19.66786494537429
# world: distance = 69.1633938736353
# destination at 84, 30
# robot at x = 28.44125721655739, y = 10.208345710584883 theta = 19.95906814190834
# world: distance = 58.978669696666266
# destination at 84, 30
# robot at x = 38.092625365913435, y = 13.522621082952604 theta = 19.3134210830183
# world: distance = 48.77490196576855
# destination at 84, 30
# robot at x = 47.142664822002274, y = 16.943695884479162 theta = 20.165153765520756
# world: distance = 39.10153748358541
# destination at 84, 30
# robot at x = 56.00995439484524, y = 19.967908744498303 theta = 19.436637526342277
# world: distance = 29.73357543144378
# destination at 84, 30
# robot at x = 65.52843904561763, y = 23.07609624567029 theta = 19.35235996452493
# world: distance = 19.72660658325918
# destination at 84, 30
# robot at x = 74.34073694974391, y = 26.512804645965044 theta = 20.489393541175396
# world: distance = 10.269464158915278
# destination at 84, 30
# robot at x = 83.05260325392892, y = 29.90281065763812 theta = 19.93040779817142
# world: distance = 96.50702587045194
# /vol/bitbucket/wbai/virt/computer_vision_ubuntu18.04/lib/python3.6/site-packages/matplotlib/pyplot.py:513: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# destination at 180, 30
# robot at x = 93.42786147822686, y = 30.32238067153969 theta = -0.07102873999488085
# world: distance = 86.57273876648735
# destination at 180, 30
# robot at x = 103.81424463997685, y = 30.208057623132618 theta = -0.34470232123749417
# world: distance = 76.18603945442918
# destination at 180, 30
# robot at x = 113.94797752224487, y = 30.272763162444576 theta = -0.27891774401019
# world: distance = 66.05258566585154
# destination at 180, 30
# robot at x = 123.92435013656551, y = 30.20227778681553 theta = -0.24348144314642955
# world: distance = 56.07601469353488
# destination at 180, 30
# robot at x = 133.55123682540508, y = 30.53820843110658 theta = -0.11192760223096902
# world: distance = 46.4518812187937
# destination at 180, 30
# robot at x = 143.32265113078557, y = 30.521774878713515 theta = -0.5819476496679128
# world: distance = 36.68106008689118
# destination at 180, 30
# robot at x = 153.5109845263884, y = 30.34693050849431 theta = -0.829840662977215
# world: distance = 26.491287275988665
# destination at 180, 30
# robot at x = 163.39154774797868, y = 30.192842584387986 theta = -0.727692350864347
# world: distance = 16.609571772626335
# destination at 180, 30
# robot at x = 173.64820174141258, y = 30.06829621617279 theta = -0.615647380464329
# world: distance = 24.02899321829239
# destination at 180, 54
# robot at x = 180.14858817036009, y = 40.05766828029446 theta = 89.74999202472401
# world: distance = 13.943123474554698
# destination at 180, 54
# robot at x = 180.2717744534098, y = 50.339905095208735 theta = 91.32019892174873
# world: distance = 42.07266208675381
# destination at 138, 54
# robot at x = 169.8603284926891, y = 53.834314753892464 theta = 179.83314417246154
# world: distance = 31.860759301417065
# destination at 138, 54
# robot at x = 160.4724574544828, y = 53.32413280481791 theta = -179.6180326487792
# world: distance = 22.48261863104613
# destination at 138, 54
# robot at x = 150.29834927946865, y = 53.01592653871975 theta = 179.93350351264576
# world: distance = 12.33765762116145
# destination at 138, 54
# robot at x = 140.49133482010927, y = 52.96441153773943 theta = 177.49436893282012
# world: distance = 115.5547595883643
# destination at 138, 168
# robot at x = 138.08340982418613, y = 61.87674905165733 theta = 89.78843195709628
# world: distance = 106.12328372719949
# destination at 138, 168
# robot at x = 137.80739787920788, y = 71.70832618846771 theta = 89.71039623922154
# world: distance = 96.29186643223542
# destination at 138, 168
# robot at x = 134.71756425357714, y = 78.78422163088128 theta = 96.04109453362278
# world: distance = 89.27614179856289
# destination at 138, 168
# robot at x = 133.40176684988924, y = 87.61968982110835 theta = 90.25912451113776
# world: distance = 80.51172593205048
# destination at 138, 168
# robot at x = 133.4382216730542, y = 96.9669183260046 theta = 87.55368550923272
# world: distance = 71.17941074221318
# destination at 138, 168
# robot at x = 135.7607714993227, y = 107.63296035167626 theta = 84.93741913546828
# world: distance = 60.408555852466264
# destination at 138, 168
# robot at x = 140.04119187403276, y = 118.59576144097367 theta = 84.37203791027508
# world: distance = 49.446387652323004
# destination at 138, 168
# robot at x = 143.18366951797103, y = 129.0608689798128 theta = 89.36886223823768
# world: distance = 39.28264698666381
# destination at 138, 168
# robot at x = 146.92693095323028, y = 139.92767007627805 theta = 94.17974459632859
# world: distance = 29.457525415248917
# destination at 138, 168
# robot at x = 147.48731964724143, y = 151.3224696621908 theta = 105.70558240559399
# world: distance = 19.1872158547685
# destination at 138, 168
# robot at x = 142.55947177603716, y = 160.00610905503243 theta = 119.66911504754071
# world: distance = 16.67908073830379
# destination at 114, 168
# robot at x = 120.69621516812718, y = 166.50187536545565 theta = 168.0740934695606
# world: distance = 86.97961037687337
# destination at 114, 84
# robot at x = 118.57781948776116, y = 161.06193572850796 theta = -93.6699247750564
# world: distance = 77.1977873354361
# destination at 114, 84
# robot at x = 115.59622951737359, y = 149.9185874340668 theta = -92.72260596383455
# world: distance = 65.93791108288801
# destination at 114, 84
# robot at x = 112.77410335072605, y = 138.7646647840204 theta = -91.27727974746735
# world: distance = 54.77838379781595
# destination at 114, 84
# robot at x = 110.27056634639082, y = 125.90417768140921 theta = -85.08861412426414
# world: distance = 42.06980844420124
# destination at 114, 84
# robot at x = 111.07744111921778, y = 115.86237828375822 theta = -85.1342778774574
# world: distance = 31.996132583625577
# destination at 114, 84
# robot at x = 108.50721444270427, y = 103.59068767882025 theta = -82.93779202083711
# world: distance = 20.34614796239121
# destination at 114, 84
# robot at x = 112.01333286426784, y = 95.24098876941619 theta = -76.11447577863495
# world: distance = 11.415194909520345
# destination at 114, 84
# robot at x = 107.47302411697754, y = 79.49980567231216 theta = -74.91769352936367
# world: distance = 27.564298319606266
# destination at 84, 84
# robot at x = 97.63718859522017, y = 72.79012551983442 theta = 141.8160388032079
# world: distance = 17.653163983905845
# destination at 84, 84
# robot at x = 85.64186588386352, y = 74.46748601205931 theta = 144.146613262209
# world: distance = 49.955964218430424
# destination at 84, 30
# robot at x = 79.33548992228947, y = 69.7240672429912 theta = -83.42598785052641
# world: distance = 39.99698954409881
# destination at 84, 30
# robot at x = 80.90120498810592, y = 59.834165810437355 theta = -82.9281800342015
# world: distance = 29.99466586128955
# destination at 84, 30
# robot at x = 81.73081337344722, y = 49.833473220645196 theta = -85.88424246703912
# world: distance = 19.962862218133353
# destination at 84, 30
# robot at x = 82.5490650206717, y = 38.057509342150894 theta = -84.44159018035025

# %% [markdown]
# # CW6

# %%
w = world.World()
w.draw_map()
w.draw_particles()
plt.imshow(w.display)

# %%
import random
import landmarks as lm
from sklearn.metrics import confusion_matrix
import pandas as pd

y_true = []
y_pred = []
correct = 0
count = 0
for i in range(100):
    landmark_placed = i%5
    angle_placed = random.random()*2*pi-pi
    x_placed, y_placed = lm.positions[landmark_placed]
    w = world.World(starting_x=x_placed,starting_y=y_placed,starting_theta=angle_placed)
    pred_lm,pred_angle = w.find_landmark_and_orientation()
    print("true landmark = "+str(landmark_placed)+", landmark predicted = "+str(pred_lm)+", true angle = "+str(angle_placed*180.0/pi)+", predicted angle = "+str(pred_angle*180.0/pi))
    print("-------------------------")
    y_true.append(landmark_placed)
    y_pred.append(pred_lm)
    if (abs(angle_placed-pred_angle)*180.0/pi < 3):
        correct += 1
    count += 1
print(">>> angle accuracy = "+str(100.0*correct/count)+" %")
# Out:
# true landmark = 0, landmark predicted = 0, true angle = 28.169684509183778, predicted angle = 27.0
# -------------------------
# true landmark = 1, landmark predicted = 1, true angle = 46.35110078487815, predicted angle = 45.0
# -------------------------
# true landmark = 2, landmark predicted = 1, true angle = -7.339839911180241, predicted angle = -95.99999999999999
# -------------------------
# true landmark = 3, landmark predicted = 3, true angle = -8.411712507696231, predicted angle = -9.0
# -------------------------
# true landmark = 4, landmark predicted = 1, true angle = 34.36095180554893, predicted angle = -57.000000000000014
# -------------------------
# true landmark = 0, landmark predicted = 0, true angle = 164.29828820003868, predicted angle = 164.99999999999997
# -------------------------
# true landmark = 1, landmark predicted = 1, true angle = 136.7124279769709, predicted angle = 137.99999999999997
# -------------------------
# true landmark = 2, landmark predicted = 1, true angle = -155.02161243226183, predicted angle = 114.0
# -------------------------
# true landmark = 3, landmark predicted = 3, true angle = -154.4480492006833, predicted angle = -153.00000000000003
# -------------------------
# true landmark = 4, landmark predicted = 2, true angle = -22.81337760193794, predicted angle = 59.99999999999999
# -------------------------
# true landmark = 0, landmark predicted = 0, true angle = 73.8608086503365, predicted angle = 72.0
# -------------------------
# true landmark = 1, landmark predicted = 2, true angle = -123.15033062421165, predicted angle = -41.999999999999986
# -------------------------
# true landmark = 2, landmark predicted = 1, true angle = -169.66640832709828, predicted angle = 102.0
# -------------------------
# true landmark = 3, landmark predicted = 3, true angle = 14.891710122315745, predicted angle = 14.999999999999998
# -------------------------
# true landmark = 4, landmark predicted = 1, true angle = -30.844557333656766, predicted angle = -120.00000000000001
# -------------------------
# true landmark = 0, landmark predicted = 0, true angle = -163.091713249758, predicted angle = -161.99999999999997
# -------------------------
# true landmark = 1, landmark predicted = 1, true angle = -58.617040782103935, predicted angle = -59.999999999999986
# -------------------------
# true landmark = 2, landmark predicted = 1, true angle = 56.810592679487414, predicted angle = -32.999999999999986
# -------------------------
# true landmark = 3, landmark predicted = 3, true angle = 78.49799475986495, predicted angle = 78.0
# -------------------------
# true landmark = 4, landmark predicted = 4, true angle = 100.02710316442135, predicted angle = 99.00000000000001
# -------------------------
# true landmark = 0, landmark predicted = 0, true angle = -76.30286618839644, predicted angle = -74.99999999999996
# -------------------------
# true landmark = 1, landmark predicted = 1, true angle = 86.66381367533205, predicted angle = 87.0
# -------------------------
# true landmark = 2, landmark predicted = 1, true angle = -121.89816804689762, predicted angle = 150.00000000000003
# -------------------------
# true landmark = 3, landmark predicted = 3, true angle = 116.2017908481936, predicted angle = 117.0
# -------------------------
# /vol/bitbucket/wbai/virt/computer_vision_ubuntu18.04/lib/python3.6/site-packages/matplotlib/pyplot.py:513: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# true landmark = 4, landmark predicted = 4, true angle = -71.76392787829043, predicted angle = -72.0
# -------------------------
# true landmark = 0, landmark predicted = 0, true angle = 145.04990937542743, predicted angle = 144.0
# -------------------------
# true landmark = 1, landmark predicted = 1, true angle = -140.00275272379477, predicted angle = -141.0
# -------------------------
# true landmark = 2, landmark predicted = 1, true angle = -72.53761099100362, predicted angle = -161.99999999999997
# -------------------------
# true landmark = 3, landmark predicted = 3, true angle = 67.52403174417958, predicted angle = 66.0
# -------------------------
# true landmark = 4, landmark predicted = 2, true angle = -18.714330526516022, predicted angle = 66.0
# -------------------------
# true landmark = 0, landmark predicted = 0, true angle = 58.302507768630605, predicted angle = 57.0
# -------------------------
# true landmark = 1, landmark predicted = 1, true angle = -95.88179852561571, predicted angle = -95.99999999999999
# -------------------------
# true landmark = 2, landmark predicted = 1, true angle = -148.3350994582104, predicted angle = 123.00000000000001
# -------------------------
# true landmark = 3, landmark predicted = 3, true angle = 164.30730539918687, predicted angle = 164.99999999999997
# -------------------------
# true landmark = 4, landmark predicted = 1, true angle = -42.27287733600568, predicted angle = -132.0
# -------------------------
# true landmark = 0, landmark predicted = 0, true angle = -54.549245142424894, predicted angle = -54.0
# -------------------------
# true landmark = 1, landmark predicted = 1, true angle = -169.23868424317527, predicted angle = -168.0
# -------------------------
# true landmark = 2, landmark predicted = 1, true angle = 119.4789421002756, predicted angle = 27.0
# -------------------------
# true landmark = 3, landmark predicted = 3, true angle = -69.95546274380125, predicted angle = -69.00000000000004
# -------------------------
# true landmark = 4, landmark predicted = 2, true angle = -39.54069416881197, predicted angle = 48.0
# -------------------------
# true landmark = 0, landmark predicted = 0, true angle = -157.83693391157988, predicted angle = -158.99999999999997
# -------------------------
# true landmark = 1, landmark predicted = 1, true angle = 53.21179000457328, predicted angle = 54.0
# -------------------------
# true landmark = 2, landmark predicted = 1, true angle = 47.80150543196981, predicted angle = -41.999999999999986
# -------------------------
# true landmark = 3, landmark predicted = 3, true angle = -0.4014433100126917, predicted angle = 0.0
# -------------------------
# true landmark = 4, landmark predicted = 2, true angle = -30.000827884126778, predicted angle = 59.99999999999999
# -------------------------
# true landmark = 0, landmark predicted = 0, true angle = 111.71695134554218, predicted angle = 111.0
# -------------------------
# true landmark = 1, landmark predicted = 1, true angle = 30.505033218423332, predicted angle = 29.999999999999996
# -------------------------
# true landmark = 2, landmark predicted = 1, true angle = 108.20389178541237, predicted angle = 18.0
# -------------------------
# true landmark = 3, landmark predicted = 3, true angle = 98.79928658556605, predicted angle = 99.00000000000001
# -------------------------
# true landmark = 4, landmark predicted = 4, true angle = -154.86595731108517, predicted angle = -156.0
# -------------------------
# true landmark = 0, landmark predicted = 0, true angle = 25.811322067703486, predicted angle = 27.0
# -------------------------
# true landmark = 1, landmark predicted = 1, true angle = -140.13317613030512, predicted angle = -141.0
# -------------------------
# true landmark = 2, landmark predicted = 1, true angle = -177.07606240979015, predicted angle = 92.99999999999999
# -------------------------
# true landmark = 3, landmark predicted = 3, true angle = 115.18601017822975, predicted angle = 114.0
# -------------------------
# true landmark = 4, landmark predicted = 2, true angle = -108.94779955539495, predicted angle = -18.0
# -------------------------
# true landmark = 0, landmark predicted = 0, true angle = 142.30139292064368, predicted angle = 141.0
# -------------------------
# true landmark = 1, landmark predicted = 1, true angle = -16.90650739781492, predicted angle = -18.0
# -------------------------
# true landmark = 2, landmark predicted = 1, true angle = -108.99534722582055, predicted angle = 159.0
# -------------------------
# true landmark = 3, landmark predicted = 3, true angle = 60.51122522201731, predicted angle = 59.99999999999999
# -------------------------
# true landmark = 4, landmark predicted = 4, true angle = -179.67751127389934, predicted angle = 180.0
# -------------------------
# true landmark = 0, landmark predicted = 0, true angle = -36.723563866859564, predicted angle = -36.0
# -------------------------
# true landmark = 1, landmark predicted = 1, true angle = 15.217663031608037, predicted angle = 14.999999999999998
# -------------------------
# true landmark = 2, landmark predicted = 1, true angle = -101.5391183172877, predicted angle = 171.0
# -------------------------
# true landmark = 3, landmark predicted = 3, true angle = 74.79953642711067, predicted angle = 75.00000000000001
# -------------------------
# true landmark = 4, landmark predicted = 4, true angle = 126.22726661814647, predicted angle = 126.0
# -------------------------
# true landmark = 0, landmark predicted = 0, true angle = -74.32637963913905, predicted angle = -74.99999999999996
# -------------------------
# true landmark = 1, landmark predicted = 1, true angle = -135.03563502706172, predicted angle = -135.0
# -------------------------
# true landmark = 2, landmark predicted = 1, true angle = 159.86865104514263, predicted angle = 68.99999999999999
# -------------------------
# true landmark = 3, landmark predicted = 3, true angle = -75.65700996259324, predicted angle = -74.99999999999996
# -------------------------
# true landmark = 4, landmark predicted = 2, true angle = 149.13165484440873, predicted angle = -126.0
# -------------------------
# true landmark = 0, landmark predicted = 0, true angle = 43.361444251645295, predicted angle = 42.0
# -------------------------
# true landmark = 1, landmark predicted = 1, true angle = 160.5489681249213, predicted angle = 162.0
# -------------------------
# true landmark = 2, landmark predicted = 1, true angle = -123.50793048625182, predicted angle = 150.00000000000003
# -------------------------
# true landmark = 3, landmark predicted = 3, true angle = 8.546063371356789, predicted angle = 9.0
# -------------------------
# true landmark = 4, landmark predicted = 4, true angle = -52.80538416384703, predicted angle = -54.0
# -------------------------
# true landmark = 0, landmark predicted = 0, true angle = 142.38968766670743, predicted angle = 141.0
# -------------------------
# true landmark = 1, landmark predicted = 1, true angle = 102.89179229490614, predicted angle = 102.0
# -------------------------
# true landmark = 2, landmark predicted = 1, true angle = -88.63587113217936, predicted angle = -177.00000000000003
# -------------------------
# true landmark = 3, landmark predicted = 3, true angle = -115.60272735304443, predicted angle = -113.99999999999997
# -------------------------
# true landmark = 4, landmark predicted = 4, true angle = 100.84133949719114, predicted angle = 99.00000000000001
# -------------------------
# true landmark = 0, landmark predicted = 0, true angle = -37.18160805182579, predicted angle = -36.0
# -------------------------
# true landmark = 1, landmark predicted = 1, true angle = -38.47690023547942, predicted angle = -39.000000000000014
# -------------------------
# true landmark = 2, landmark predicted = 1, true angle = -62.35059809417158, predicted angle = -153.00000000000003
# -------------------------
# true landmark = 3, landmark predicted = 3, true angle = -56.692286994702975, predicted angle = -57.000000000000014
# -------------------------
# true landmark = 4, landmark predicted = 4, true angle = 144.17550930813852, predicted angle = 144.0
# -------------------------
# true landmark = 0, landmark predicted = 0, true angle = 34.14422900801838, predicted angle = 36.0
# -------------------------
# true landmark = 1, landmark predicted = 1, true angle = 155.88364199498298, predicted angle = 156.0
# -------------------------
# true landmark = 2, landmark predicted = 1, true angle = 132.65809616986488, predicted angle = 42.0
# -------------------------
# true landmark = 3, landmark predicted = 3, true angle = -55.35763367348507, predicted angle = -57.000000000000014
# -------------------------
# true landmark = 4, landmark predicted = 1, true angle = -156.86523276736045, predicted angle = -158.99999999999997
# -------------------------
# true landmark = 0, landmark predicted = 0, true angle = -177.6980642717556, predicted angle = -177.00000000000003
# -------------------------
# true landmark = 1, landmark predicted = 1, true angle = -87.4933711754971, predicted angle = -86.99999999999997
# -------------------------
# true landmark = 2, landmark predicted = 1, true angle = 105.19171592701022, predicted angle = 18.0
# -------------------------
# true landmark = 3, landmark predicted = 3, true angle = -100.58233331552006, predicted angle = -102.00000000000001
# -------------------------
# true landmark = 4, landmark predicted = 4, true angle = 99.05536168706185, predicted angle = 99.00000000000001
# -------------------------
# true landmark = 0, landmark predicted = 0, true angle = -53.549795576055324, predicted angle = -54.0
# -------------------------
# true landmark = 1, landmark predicted = 1, true angle = -80.23845604796541, predicted angle = -78.00000000000003
# -------------------------
# true landmark = 2, landmark predicted = 1, true angle = -77.22897024953929, predicted angle = -168.0
# -------------------------
# true landmark = 3, landmark predicted = 3, true angle = -99.1054332040665, predicted angle = -99.00000000000001
# -------------------------
# true landmark = 4, landmark predicted = 4, true angle = 170.34843511452905, predicted angle = 171.0
# -------------------------
# >>> angle accuracy = 69.0 %

# %%
confusion = confusion_matrix(y_true,y_pred)
plt.figure(figsize = (7,5))
plt.matshow(confusion)
plt.colorbar()

# %%
w.set_robot_at(138,54,-156.527*pi/180.0)

# %%
w.measure_around()
# Out:
# [70.55884060341045,
#  70.14449568237384,
#  56.676048760643695,
#  255,
#  47.96570378567004,
#  255,
#  47.33367233904997,
#  42.802741866588434,
#  45.57732959409373,
#  45.50006302868329,
#  48.117591864588576,
#  48.86916330962083,
#  57.156430390088126,
#  65.47060476095156,
#  85.68694307764393,
#  78.43957081546353,
#  255,
#  101.14539814249845,
#  127.80106936144398,
#  160.3641930534582,
#  155.69781653424863,
#  255,
#  157.35804221292207,
#  130.0958489859832,
#  156.8351014576696,
#  155.55258992544876,
#  156.9117126472926,
#  163.1148868868531,
#  161.91366140500017,
#  153.2153962430935,
#  57.99404688528512,
#  159.16363732204752,
#  255,
#  148.61901685951634,
#  155.64816244523095,
#  165.74628684238786,
#  150.96846115727394,
#  57.08460347930937,
#  155.89239001210052,
#  86.60791351186063,
#  176.7528427522025,
#  152.27688028977988,
#  146.77042249266205,
#  255,
#  157.74492639706736,
#  87.01728134288997,
#  255,
#  141.1186638398009,
#  146.8428164355981,
#  136.62043723303373,
#  141.15240445206004,
#  255,
#  135.6654963639127,
#  140.13930205778865,
#  136.36084433759783,
#  142.70543158847227,
#  141.8817803556862,
#  139.9389773446082,
#  255,
#  142.282309063731,
#  129.1659911460537,
#  121.32805971440821,
#  110.27257998184656,
#  102.1690612323365,
#  52.6608232575305,
#  147.4096173928045,
#  84.40901946285722,
#  74.34812690803605,
#  111.61917530010992,
#  255,
#  155.05808025436824,
#  255,
#  54.872289653969226,
#  79.09754841872746,
#  57.11481234479298,
#  71.35622863916483,
#  255,
#  133.88234440717193,
#  56.262660827216386,
#  50.72424894560483,
#  49.846975805460296,
#  54.672745760859954,
#  52.57606851193986,
#  52.42183005232844,
#  54.72723832715673,
#  58.21024972074506,
#  51.898942330432554,
#  57.75498327539659,
#  51.90733471222881,
#  60.47666207663155,
#  55.52522355271829,
#  59.786338931433775,
#  255,
#  59.22684422933659,
#  67.05980990198638,
#  66.06755186819045,
#  72.24762332257342,
#  80.25013651048235,
#  255,
#  79.83466699709199,
#  92.36725740062546,
#  84.79191675249639,
#  84.04174394293791,
#  83.57895316952354,
#  80.46737856018542,
#  255,
#  76.48905242335151,
#  70.91938863056988,
#  73.67879559875436,
#  71.22808743225939,
#  80.3818736971659,
#  255,
#  70.8337481298972,
#  75.57813465594431,
#  255,
#  72.86546120643915,
#  73.22200233471204,
#  79.29780588661423,
#  74.89112009784098,
#  78.15316908676093]

# %%
a = lm.ground_truth_measurements[3]

# %%
a
# Out:
# [138.0,
#  138.1893837477131,
#  138.76014257976527,
#  139.7201873587444,
#  141.08300209137403,
#  142.86811289659147,
#  145.1017869448809,
#  147.81800912191002,
#  132.76404012100878,
#  118.94522028760437,
#  108.00000000000001,
#  99.14823677393986,
#  91.87028730202029,
#  85.80684936955048,
#  80.70173369268889,
#  76.36753236814712,
#  72.66416739874431,
#  69.48501655823104,
#  66.74767078498864,
#  64.38761781314116,
#  62.35382907247959,
#  60.605616832255485,
#  59.110359039326525,
#  57.84182965639957,
#  56.77896010886643,
#  55.90491374214449,
#  55.20639212271158,
#  54.67311679255216,
#  54.29744709642989,
#  54.074106683887734,
#  54.0,
#  54.074106683887734,
#  54.29744709642989,
#  54.67311679255216,
#  55.20639212271158,
#  55.90491374214449,
#  56.778960108866436,
#  57.84182965639957,
#  59.110359039326525,
#  60.605616832255485,
#  62.353829072479584,
#  64.38761781314116,
#  66.74767078498864,
#  69.48501655823104,
#  72.6641673987443,
#  76.36753236814712,
#  80.70173369268885,
#  85.80684936955045,
#  88.99689437998487,
#  85.85015708418823,
#  83.13843876330613,
#  80.80748910967397,
#  78.81381205243537,
#  77.1224395418661,
#  75.70528014515524,
#  74.53988498952599,
#  73.60852283028211,
#  72.89748905673622,
#  72.39659612857318,
#  72.09880891185031,
#  72.0,
#  72.09880891185031,
#  72.39659612857317,
#  72.89748905673622,
#  73.6085228302821,
#  74.53988498952597,
#  75.70528014515524,
#  77.12243954186609,
#  73.7578000672272,
#  66.08067793755801,
#  60.00000000000002,
#  55.08235376329992,
#  51.0390485011224,
#  47.670471871972495,
#  44.834296495938275,
#  42.426406871192846,
#  44.83429649593825,
#  47.67047187197246,
#  51.03904850112239,
#  55.08235376329984,
#  59.99999999999996,
#  66.080677937558,
#  73.75780006722702,
#  83.71284328876,
#  97.08203932499367,
#  115.91109915468789,
#  144.2920303423237,
#  157.94455962292847,
#  156.85929161190856,
#  156.2140859756757,
#  156.0,
#  156.21408597567566,
#  156.85929161190853,
#  157.94455962292847,
#  159.48513279894453,
#  161.50308414397296,
#  164.02810698116969,
#  150.6831179197684,
#  132.76404012100897,
#  118.94522028760441,
#  108.00000000000013,
#  99.14823677393987,
#  91.87028730202033,
#  146.69059051182097,
#  153.40213117512684,
#  161.22034611053283,
#  170.37032668456527,
#  177.57282009325712,
#  170.577380894971,
#  164.5461344113608,
#  159.34867429633672,
#  154.8810207935418,
#  151.0598064338345,
#  147.81800912191002,
#  145.1017869448809,
#  142.8681128965915,
#  141.08300209137406,
#  139.7201873587444,
#  138.76014257976527,
#  138.1893837477131]

# %%
import numpy as np
np.roll(a,-68)
# Out:
# array([ 73.75780007,  66.08067794,  60.        ,  55.08235376,
#         51.0390485 ,  47.67047187,  44.8342965 ,  42.42640687,
#         44.8342965 ,  47.67047187,  51.0390485 ,  55.08235376,
#         60.        ,  66.08067794,  73.75780007,  83.71284329,
#         97.08203932, 115.91109915, 144.29203034, 157.94455962,
#        156.85929161, 156.21408598, 156.        , 156.21408598,
#        156.85929161, 157.94455962, 159.4851328 , 161.50308414,
#        164.02810698, 150.68311792, 132.76404012, 118.94522029,
#        108.        ,  99.14823677,  91.8702873 , 146.69059051,
#        153.40213118, 161.22034611, 170.37032668, 177.57282009,
#        170.57738089, 164.54613441, 159.3486743 , 154.88102079,
#        151.05980643, 147.81800912, 145.10178694, 142.8681129 ,
#        141.08300209, 139.72018736, 138.76014258, 138.18938375,
#        138.        , 138.18938375, 138.76014258, 139.72018736,
#        141.08300209, 142.8681129 , 145.10178694, 147.81800912,
#        132.76404012, 118.94522029, 108.        ,  99.14823677,
#         91.8702873 ,  85.80684937,  80.70173369,  76.36753237,
#         72.6641674 ,  69.48501656,  66.74767078,  64.38761781,
#         62.35382907,  60.60561683,  59.11035904,  57.84182966,
#         56.77896011,  55.90491374,  55.20639212,  54.67311679,
#         54.2974471 ,  54.07410668,  54.        ,  54.07410668,
#         54.2974471 ,  54.67311679,  55.20639212,  55.90491374,
#         56.77896011,  57.84182966,  59.11035904,  60.60561683,
#         62.35382907,  64.38761781,  66.74767078,  69.48501656,
#         72.6641674 ,  76.36753237,  80.70173369,  85.80684937,
#         88.99689438,  85.85015708,  83.13843876,  80.80748911,
#         78.81381205,  77.12243954,  75.70528015,  74.53988499,
#         73.60852283,  72.89748906,  72.39659613,  72.09880891,
#         72.        ,  72.09880891,  72.39659613,  72.89748906,
#         73.60852283,  74.53988499,  75.70528015,  77.12243954])

# %%
print(w.r.particle_cloud)
# Out:
# x = 138, y = 54, theta = -167.6452855291256, w = 0.05
# x = 138, y = 54, theta = -101.9306962879618, w = 0.05
# x = 138, y = 54, theta = -62.72708146712752, w = 0.05
# x = 138, y = 54, theta = -110.38492327224095, w = 0.05
# x = 138, y = 54, theta = -183.7997741603416, w = 0.05
# x = 138, y = 54, theta = -112.91734660450861, w = 0.05
# x = 138, y = 54, theta = -181.93857903530906, w = 0.05
# x = 138, y = 54, theta = -302.89124133345257, w = 0.05
# x = 138, y = 54, theta = -152.6590762247623, w = 0.05
# x = 138, y = 54, theta = -147.02708882259108, w = 0.05
# x = 138, y = 54, theta = -206.7018182316675, w = 0.05
# x = 138, y = 54, theta = -153.36636911732302, w = 0.05
# x = 138, y = 54, theta = -112.9685433174082, w = 0.05
# x = 138, y = 54, theta = -149.41912276950896, w = 0.05
# x = 138, y = 54, theta = -181.58094615251613, w = 0.05
# x = 138, y = 54, theta = -161.91212134851864, w = 0.05
# x = 138, y = 54, theta = -115.23070239756385, w = 0.05
# x = 138, y = 54, theta = -165.08173742041387, w = 0.05
# x = 138, y = 54, theta = -137.558682212457, w = 0.05
# x = 138, y = 54, theta = -212.47269445860366, w = 0.05
# -----------------------------------------
# avg_x = 138.00000000000003, y = 54.000000000000014, theta = -156.0106915081701
# ====== done printing particles =======

# %%
w.rotate_robot(pi*2.0/120)

# %%
print(w.r.particle_cloud)
# Out:
# x = 138, y = 54, theta = -164.6869678479211, w = 0.05
# x = 138, y = 54, theta = -98.91786546993495, w = 0.05
# x = 138, y = 54, theta = -59.73109556300113, w = 0.05
# x = 138, y = 54, theta = -107.50175004071126, w = 0.05
# x = 138, y = 54, theta = -180.69966225082095, w = 0.05
# x = 138, y = 54, theta = -109.89285728839508, w = 0.05
# x = 138, y = 54, theta = -178.89150075937158, w = 0.05
# x = 138, y = 54, theta = -299.8873515982904, w = 0.05
# x = 138, y = 54, theta = -149.64608682898333, w = 0.05
# x = 138, y = 54, theta = -144.02999228282798, w = 0.05
# x = 138, y = 54, theta = -203.63608070607495, w = 0.05
# x = 138, y = 54, theta = -150.41950198709154, w = 0.05
# x = 138, y = 54, theta = -109.89686526463092, w = 0.05
# x = 138, y = 54, theta = -146.43271966452974, w = 0.05
# x = 138, y = 54, theta = -178.71015564625495, w = 0.05
# x = 138, y = 54, theta = -158.90954743178196, w = 0.05
# x = 138, y = 54, theta = -112.17402848025544, w = 0.05
# x = 138, y = 54, theta = -162.20332155491477, w = 0.05
# x = 138, y = 54, theta = -134.5447414987421, w = 0.05
# x = 138, y = 54, theta = -209.59147347827712, w = 0.05
# -----------------------------------------
# avg_x = 138.00000000000003, y = 54.000000000000014, theta = -153.0201782821406
# ====== done printing particles =======

# %%
w.measure_around()
# Out:
# [69.25911594864175,
#  59.93346244718213,
#  55.05269805759575,
#  51.00072738151858,
#  50.071593774449326,
#  47.530581940838005,
#  49.41441495967318,
#  52.08786721755902,
#  53.22373211902817,
#  255,
#  54.09392337284328,
#  43.227122333809334,
#  146.38080384529778,
#  38.109515982022316,
#  75.93714993586951,
#  98.86155936595117,
#  109.50350305680098,
#  142.66865049870898,
#  255,
#  158.8746702538197,
#  157.99800788719887,
#  152.75009606959793,
#  255,
#  157.37019682043586,
#  158.41742588074777,
#  255,
#  77.97134131229919,
#  165.26751223565614,
#  74.94321443113552,
#  153.79675000853382,
#  80.76605297896577,
#  108.48205207183281,
#  79.00234894264113,
#  255,
#  255,
#  156.80759518970842,
#  255,
#  255,
#  163.44830910472967,
#  160.04128195461334,
#  43.50487506297306,
#  130.87783969699754,
#  74.87231541442395,
#  145.72710720228125,
#  145.26007266137526,
#  149.40431161803144,
#  138.17715189845006,
#  143.27243235072947,
#  142.28638370955315,
#  255,
#  132.57673841680855,
#  136.07057502009818,
#  134.81347742211747,
#  255,
#  140.34772779961918,
#  140.50041209104344,
#  148.8899653368905,
#  145.8463410763872,
#  146.51559758351212,
#  131.74423188638167,
#  124.35866363096426,
#  110.92371480783422,
#  102.09662198464756,
#  255,
#  255,
#  144.50611045071824,
#  122.25000672947132,
#  255,
#  79.02589693347878,
#  62.237297104568135,
#  66.92156854712576,
#  62.013089947563174,
#  64.29831452017882,
#  57.084139026796095,
#  77.08329404315931,
#  255,
#  255,
#  255,
#  60.109155705547956,
#  255,
#  78.47121605034467,
#  52.2575743121881,
#  74.40203918510554,
#  255,
#  255,
#  58.56704429983288,
#  255,
#  54.03153765387378,
#  65.56753670763975,
#  59.24561425640803,
#  59.80888549580019,
#  62.76823075228234,
#  61.18190041269438,
#  67.006935351774,
#  255,
#  72.37519733481462,
#  74.69967564450334,
#  77.12593344859572,
#  85.54039109675367,
#  86.46157994713184,
#  85.6420607401401,
#  86.20680079948936,
#  80.19735634675848,
#  80.21378940294295,
#  86.45618171396268,
#  76.09099323460836,
#  255,
#  72.109564491997,
#  74.2272015862157,
#  70.92749526240323,
#  68.37759923527491,
#  69.91693296613789,
#  71.8928896625226,
#  255,
#  70.29105301214939,
#  74.23156793699121,
#  255,
#  73.79209191296344,
#  72.80106965322078,
#  73.71739263761408]
