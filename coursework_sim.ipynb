# %%
import world
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # CW4

# %%
w = world.World()
w.draw_map()
w.draw_particles()
plt.imshow(w.display)

# %%
from math import pi
for j in range(4):
    for i in range(4):
        w.move_robot_forward(10)

    w.rotate_robot(pi/2.0)

# %% [markdown]
# # CW5

# %%
w = world.World()
w.draw_map()
w.draw_particles()
plt.imshow(w.display)

# %%
w.move_robot_to(84,30)
w.move_robot_to(180,30)
w.move_robot_to(180,54)
w.move_robot_to(138,54)
w.move_robot_to(138,168)
w.move_robot_to(114,168)
w.move_robot_to(114,84)
w.move_robot_to(84,84)
w.move_robot_to(84,30)

# %%
w = world.World()
w.draw_map()
w.draw_particles()
plt.imshow(w.display)

# %%
w.move_robot_to_slam(84,30)
w.move_robot_to_slam(180,30)
w.move_robot_to_slam(180,54)
w.move_robot_to_slam(138,54)
w.move_robot_to_slam(138,168)
w.move_robot_to_slam(114,168)
w.move_robot_to_slam(114,84)
w.move_robot_to_slam(84,84)
w.move_robot_to_slam(84,30)
# Out:
# world: distance = 89.19641248391103
# destination at 84, 30
# robot at x = 9.498683754608193, y = 3.387070941444646 theta = 0.34098623486633445
# world: distance = 79.11190880879806
# destination at 84, 30
# robot at x = 18.805625489177146, y = 6.723743466729882 theta = 0.3424258506561699
# world: distance = 69.22492749046421
# destination at 84, 30
# robot at x = 28.50908499336984, y = 10.209255928428204 theta = 0.3451553238668251
# world: distance = 58.91447359672754
# destination at 84, 30
# robot at x = 37.59439572034669, y = 13.421187740706793 theta = 0.33933429241889657
# world: distance = 49.27816072550465
# destination at 84, 30
# robot at x = 47.1752379845443, y = 16.824268103822973 theta = 0.342729478556649
# world: distance = 39.11090651589254
# destination at 84, 30
# robot at x = 57.00012172302915, y = 20.43190903811195 theta = 0.34713333490405013
# world: distance = 28.64510065659058
# destination at 84, 30
# robot at x = 66.49482394018557, y = 23.897296234256803 theta = 0.3433664407869016
# world: distance = 18.53845144928552
# destination at 84, 30
# robot at x = 75.86368427834473, y = 26.88287405345607 theta = 0.3319617480165916
# world: distance = 94.96809885319703
# destination at 180, 30
# robot at x = 95.02523286471443, y = 30.336078427327713 theta = -0.007303399335973284
# world: distance = 84.9754317341508
# destination at 180, 30
# robot at x = 105.35762591178613, y = 30.61101106371525 theta = -0.007452551182526913
# world: distance = 74.64487486790264
# destination at 180, 30
# robot at x = 115.53345468443769, y = 30.658636212676853 theta = -0.008671355045260587
# world: distance = 64.46990977645383
# destination at 180, 30
# robot at x = 125.4840651701864, y = 30.67790415191468 theta = -0.008274526339657756
# world: distance = 54.52014952664443
# destination at 180, 30
# robot at x = 136.01151374472957, y = 30.53124120339058 theta = -0.013360010334717305
# world: distance = 43.99169399155135
# D:\Users\ONE10\Anaconda3\envs\tfdeeplearning\lib\site-packages\matplotlib\pyplot.py:528: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# destination at 180, 30
# robot at x = 144.86768182207967, y = 29.78595840097696 theta = -0.018585591158103886
# world: distance = 35.13297018984793
# destination at 180, 30
# robot at x = 155.48979213449866, y = 29.81484376324267 theta = 0.006065676916680816
# world: distance = 24.510907213771056
# destination at 180, 30
# robot at x = 165.19045282810697, y = 29.939455781773265 theta = 0.008922470193204867
# world: distance = 14.80967092945976
# destination at 180, 30
# robot at x = 175.31681660644333, y = 30.071752203068392 theta = 0.006513948361662233
# world: distance = 23.862335627290758
# destination at 180, 54
# robot at x = 180.17604264029654, y = 40.147464129770675 theta = 1.5730282819422157
# world: distance = 13.853654429326317
# destination at 180, 54
# robot at x = 179.62897675631663, y = 49.971037229183914 theta = 1.5969732709999311
# world: distance = 41.175953624188075
# destination at 138, 54
# robot at x = 169.1902294002617, y = 54.220237662656345 theta = -0.5978443378763737
# world: distance = 31.191006951828307
# destination at 138, 54
# robot at x = 176.07349291515933, y = 60.21174498824347 theta = 2.859211588947219
# world: distance = 38.57689254670023
# destination at 138, 54
# robot at x = 180.43468735280092, y = 69.1076342290926 theta = 1.1211146072169018
# world: distance = 45.04379316542971
# destination at 138, 54
# robot at x = 170.87695141818074, y = 65.58276158093933 theta = -2.787886823076929
# world: distance = 34.85762901280437
# destination at 138, 54
# robot at x = 161.58047942283196, y = 60.84892141538396 theta = -2.7341663419234497
# world: distance = 24.554973719487187
# destination at 138, 54
# robot at x = 151.57188458137034, y = 57.67392694229686 theta = -2.839345649606223
# world: distance = 14.060362380371735
# destination at 138, 54
# robot at x = 141.69819711805692, y = 54.6416445494071 theta = -2.8679150071650055
# world: distance = 113.82098282146515
# destination at 138, 168
# robot at x = 138.066566489188, y = 64.24081653168554 theta = 1.5863768278351935
# world: distance = 103.75920482110888
# destination at 138, 168
# robot at x = 139.2869215009663, y = 75.01829048470107 theta = 1.528539466577263
# world: distance = 92.99061496375363
# destination at 138, 168
# robot at x = 139.4221702891699, y = 85.84368697853398 theta = 1.611231716630434
# world: distance = 82.16862136857661
# destination at 138, 168
# robot at x = 138.48303953882728, y = 96.73337306351394 theta = 1.6337630118609907
# world: distance = 71.26826391950594
# destination at 138, 168
# robot at x = 138.04444037977987, y = 106.79508358263473 theta = 1.589598723651148
# world: distance = 61.204932551257855
# destination at 138, 168
# robot at x = 138.42062107937167, y = 117.43693062080865 theta = 1.5763597615319407
# world: distance = 50.56481886783863
# destination at 138, 168
# robot at x = 138.33625847329137, y = 127.72232948639724 theta = 1.5800405453439188
# world: distance = 40.27907411750182
# destination at 138, 168
# robot at x = 138.30598478246463, y = 137.612626144557 theta = 1.5786520938980786
# world: distance = 30.388914368854326
# destination at 138, 168
# robot at x = 138.2056719093725, y = 147.60593825501888 theta = 1.581284575412029
# world: distance = 20.39509880810601
# destination at 138, 168
# robot at x = 138.32785770379158, y = 156.89520646747764 theta = 1.5745480176739095
# world: distance = 11.109632310472117
# destination at 138, 168
# robot at x = 138.13368576616088, y = 166.71396223730824 theta = 1.597771998638295
# world: distance = 24.14882787154622
# destination at 114, 168
# robot at x = 127.9518565394408, y = 168.04574776381398 theta = 3.126016456134862
# world: distance = 13.951931542085164
# destination at 114, 168
# robot at x = 118.02696277373327, y = 167.17405480552733 theta = -1.5046494003522726
# world: distance = 81.91287528880797
# destination at 114, 84
# robot at x = 106.11973714293238, y = 160.19859609157902 theta = -2.5172294895562204
# world: distance = 76.60499062740026
# destination at 114, 84
# robot at x = 106.71835691241284, y = 150.68297802568634 theta = -1.4800191960776523
# world: distance = 67.07937003601907
# destination at 114, 84
# robot at x = 106.33517556679783, y = 141.70566811796607 theta = -1.5085312046953585
# world: distance = 58.21248720448783
# destination at 114, 84
# robot at x = 102.39840851409906, y = 134.18308712395566 theta = -1.591340231402291
# world: distance = 51.50669042266503
# destination at 114, 84
# robot at x = 103.16172902926571, y = 124.95296223836223 theta = -1.3810339747144067
# world: distance = 42.36287565465528
# destination at 114, 84
# robot at x = 103.25688187972692, y = 115.68308528289279 theta = -1.3635064009442102
# world: distance = 33.454932072703386
# destination at 114, 84
# robot at x = 106.48406269371498, y = 106.46191748756443 theta = -1.2417700068464208
# world: distance = 23.68600960082048
# destination at 114, 84
# robot at x = 109.51295390159012, y = 96.84442175754099 theta = -1.251089587593319
# world: distance = 13.605614759166436
# destination at 114, 84
# robot at x = 112.46959277873259, y = 87.49257799938236 theta = -1.2375886842316923
# world: distance = 29.72469536682317
# destination at 84, 84
# robot at x = 103.68391228577183, y = 84.24273180757582 theta = 3.0992479949553946
# world: distance = 19.68540885032282
# destination at 84, 84
# robot at x = 93.85388237716757, y = 83.31938167604304 theta = 0.046456273126390696
# world: distance = 54.02001320896215
# destination at 84, 30
# robot at x = 89.792289991623, y = 91.93399843336562 theta = 0.9363683961465605
# world: distance = 62.20426661645639
# destination at 84, 30
# robot at x = 89.31013004251264, y = 81.69373911869646 theta = -1.5522637840331217
# world: distance = 51.96575935306097
# destination at 84, 30
# robot at x = 87.84160911337248, y = 72.96144255315338 theta = -1.7362324348844898
# world: distance = 43.13285878338977
# destination at 84, 30
# robot at x = 85.52234599561532, y = 63.12933949034066 theta = -1.7019018883490147
# world: distance = 33.16429815926475
# destination at 84, 30
# robot at x = 82.72067603210655, y = 54.230160974930826 theta = -1.6764717150391246
# world: distance = 24.26391086955867
# destination at 84, 30
# robot at x = 81.5746760842739, y = 44.01785509508185 theta = -1.5648322894166125
# world: distance = 14.226118851004482
# destination at 84, 30
# robot at x = 82.2752588019057, y = 34.14947015861641 theta = -1.4188968365361068

# %% [markdown]
# # CW6

# %%
w = world.World()
w.draw_map()
w.draw_particles()
plt.imshow(w.display)

# %%
import random
import landmarks as lm
for i in range(100):
    landmark_placed = random.randint(0,4)
    angle_placed = random.random()*2*pi-pi
    x_placed, y_placed = lm.positions[landmark_placed]
    w = world.World(starting_x=x_placed,starting_y=y_placed,starting_theta=angle_placed)
    
    landmark_pred =
